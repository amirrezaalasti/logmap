# %% [markdown]
# # this file is for testing the implementations in easier way with jupyter

# %%
from ontology_loader import OntologyLoader

source_address = 'data/mouse-human/source.xml'
target_address = 'data/mouse-human/target.xml'

source_ontology = OntologyLoader(source_address)
target_ontology = OntologyLoader(target_address)

source_ontology.load()
target_ontology.load()
# Out:
# Ontology loaded successfully from data/mouse-human/source.xml
# Ontology loaded successfully from data/mouse-human/target.xml
# get_ontology("http://human.owl#")

# %%
len(list(source_ontology.ontology.classes()))
# Out:
# 2744

# %%
print(list(source_ontology.ontology.classes())[520].label)
print(list(source_ontology.ontology.classes())[2031].label)
# Out:
# ['lobar bronchus']
# ['median dorsal digital artery for digit 01']

# %%
parents1 = source_ontology.ontology.get_parents_of(list(source_ontology.ontology.classes())[520])
parents2 = source_ontology.ontology.get_parents_of(list(source_ontology.ontology.classes())[2031])


print(parents1[0].label, parents2[0].label)
# Out:
# ['bronchus'] ['forelimb digital arteries']

# %%
source_ontology.ontology.get_triples()
# Out:
# [(303, 6, 80),
#  (304, 6, 15),
#  (305, 6, 15),
#  (306, 6, 15),
#  (307, 6, 15),
#  (308, 6, 15),
#  (40, 6, 15),
#  (309, 6, 15),
#  (310, 6, 13),
#  (311, 6, 13),
#  (312, 6, 13),
#  (313, 6, 11),
#  (314, 6, 11),
#  (314, 9, 315),
#  (-1, 6, 17),
#  (-1, 18, 311),
#  (-1, 24, 316),
#  (314, 9, -1),
#  (317, 6, 11),
#  (317, 9, 34),
#  (-2, 6, 17),
#  (-2, 18, 311),
#  (-2, 24, 318),
#  (317, 9, -2),
#  (319, 6, 11),
#  (319, 9, 320),
#  (319, 304, 321),
#  (322, 6, 11),
#  (322, 9, 320),
#  (323, 6, 11),
#  (323, 9, 320),
#  (324, 6, 11),
#  (324, 9, 320),
#  (324, 304, 325),
#  (326, 6, 11),
#  (326, 9, 320),
#  (327, 6, 11),
#  (327, 9, 328),
#  (329, 6, 11),
#  (329, 9, 317),
#  (329, 304, 330),
#  (328, 6, 11),
#  (328, 9, 317),
#  (331, 6, 11),
#  (331, 9, 317),
#  (332, 6, 11),
#  (332, 9, 317),
#  (332, 304, 333),
#  (334, 6, 11),
#  (334, 9, 317),
#  (335, 6, 11),
#  (335, 9, 34),
#  (-3, 6, 17),
#  (-3, 18, 311),
#  (-3, 24, 336),
#  (335, 9, -3),
#  (337, 6, 11),
#  (337, 9, 317),
#  (338, 6, 11),
#  (338, 9, 34),
#  (-4, 6, 17),
#  (-4, 18, 311),
#  (-4, 24, 339),
#  (338, 9, -4),
#  (340, 6, 11),
#  (340, 9, 34),
#  (-5, 6, 17),
#  (-5, 18, 311),
#  (-5, 24, 336),
#  (340, 9, -5),
#  (341, 6, 11),
#  (341, 9, 317),
#  (342, 6, 11),
#  (342, 9, 34),
#  (-6, 6, 17),
#  (-6, 18, 311),
#  (-6, 24, 319),
#  (342, 9, -6),
#  (343, 6, 11),
#  (343, 9, 34),
#  (-7, 6, 17),
#  (-7, 18, 311),
#  (-7, 24, 319),
#  (343, 9, -7),
#  (343, 304, 344),
#  (345, 6, 11),
#  (345, 9, 34),
#  (-8, 6, 17),
#  (-8, 18, 311),
#  (-8, 24, 319),
#  (345, 9, -8),
#  (345, 304, 346),
#  (347, 6, 11),
#  (347, 9, 34),
#  (-9, 6, 17),
#  (-9, 18, 311),
#  (-9, 24, 323),
#  (347, 9, -9),
#  (348, 6, 11),
#  (348, 9, 34),
#  (-10, 6, 17),
#  (-10, 18, 311),
#  (-10, 24, 323),
#  (348, 9, -10),
#  (349, 6, 11),
#  (349, 9, 324),
#  (350, 6, 11),
#  (350, 9, 324),
#  (351, 6, 11),
#  (351, 9, 34),
#  (-11, 6, 17),
#  (-11, 18, 311),
#  (-11, 24, 343),
#  (351, 9, -11),
#  (352, 6, 11),
#  (352, 9, 34),
#  (-12, 6, 17),
#  (-12, 18, 311),
#  (-12, 24, 345),
#  (352, 9, -12),
#  (353, 6, 11),
#  (353, 9, 34),
#  (-13, 6, 17),
#  (-13, 18, 311),
#  (-13, 24, 343),
#  (353, 9, -13),
#  (354, 6, 11),
#  (354, 9, 34),
#  (-14, 6, 17),
#  (-14, 18, 311),
#  (-14, 24, 343),
#  (354, 9, -14),
#  (355, 6, 11),
#  (355, 9, 34),
#  (-15, 6, 17),
#  (-15, 18, 311),
#  (-15, 24, 345),
#  (355, 9, -15),
#  (355, 304, 356),
#  (357, 6, 11),
#  (357, 9, 34),
#  (-16, 6, 17),
#  (-16, 18, 311),
#  (-16, 24, 345),
#  (357, 9, -16),
#  (358, 6, 11),
#  (358, 9, 34),
#  (-17, 6, 17),
#  (-17, 18, 311),
#  (-17, 24, 349),
#  (358, 9, -17),
#  (359, 6, 11),
#  (359, 9, 34),
#  (-18, 6, 17),
#  (-18, 18, 311),
#  (-18, 24, 358),
#  (359, 9, -18),
#  (359, 304, 360),
#  (361, 6, 11),
#  (361, 9, 34),
#  (-19, 6, 17),
#  (-19, 18, 311),
#  (-19, 24, 358),
#  (361, 9, -19),
#  (362, 6, 11),
#  (362, 9, 34),
#  (-20, 6, 17),
#  (-20, 18, 311),
#  (-20, 24, 349),
#  (362, 9, -20),
#  (363, 6, 11),
#  (363, 9, 364),
#  (-21, 6, 17),
#  (-21, 18, 311),
#  (-21, 24, 349),
#  (363, 9, -21),
#  (365, 6, 11),
#  (365, 9, 34),
#  (-22, 6, 17),
#  (-22, 18, 311),
#  (-22, 24, 349),
#  (365, 9, -22),
#  (366, 6, 11),
#  (366, 9, 34),
#  (-23, 6, 17),
#  (-23, 18, 311),
#  (-23, 24, 349),
#  (366, 9, -23),
#  (367, 6, 11),
#  (367, 9, 34),
#  (-24, 6, 17),
#  (-24, 18, 311),
#  (-24, 24, 363),
#  (367, 9, -24),
#  (368, 6, 11),
#  (368, 9, 369),
#  (-25, 6, 17),
#  (-25, 18, 311),
#  (-25, 24, 363),
#  (368, 9, -25),
#  (370, 6, 11),
#  (370, 9, 34),
#  (-26, 6, 17),
#  (-26, 18, 311),
#  (-26, 24, 363),
#  (370, 9, -26),
#  (371, 6, 11),
#  (371, 9, 34),
#  (-27, 6, 17),
#  (-27, 18, 311),
#  (-27, 24, 350),
#  (371, 9, -27),
#  (372, 6, 11),
#  (372, 9, 364),
#  (-28, 6, 17),
#  (-28, 18, 311),
#  (-28, 24, 350),
#  (372, 9, -28),
#  (373, 6, 11),
#  (373, 9, 34),
#  (-29, 6, 17),
#  (-29, 18, 311),
#  (-29, 24, 350),
#  (373, 9, -29),
#  (374, 6, 11),
#  (374, 9, 34),
#  (-30, 6, 17),
#  (-30, 18, 311),
#  (-30, 24, 350),
#  (374, 9, -30),
#  (375, 6, 11),
#  (375, 9, 34),
#  (-31, 6, 17),
#  (-31, 18, 311),
#  (-31, 24, 350),
#  (375, 9, -31),
#  (376, 6, 11),
#  (376, 9, 369),
#  (-32, 6, 17),
#  (-32, 18, 311),
#  (-32, 24, 372),
#  (376, 9, -32),
#  (377, 6, 11),
#  (377, 9, 34),
#  (-33, 6, 17),
#  (-33, 18, 311),
#  (-33, 24, 372),
#  (377, 9, -33),
#  (378, 6, 11),
#  (378, 9, 34),
#  (-34, 6, 17),
#  (-34, 18, 311),
#  (-34, 24, 372),
#  (378, 9, -34),
#  (379, 6, 11),
#  (379, 9, 34),
#  (-35, 6, 17),
#  (-35, 18, 311),
#  (-35, 24, 375),
#  (379, 9, -35),
#  (380, 6, 11),
#  (380, 9, 34),
#  (-36, 6, 17),
#  (-36, 18, 311),
#  (-36, 24, 375),
#  (380, 9, -36),
#  (381, 6, 11),
#  (381, 9, 382),
#  (383, 6, 11),
#  (383, 9, 382),
#  (384, 6, 11),
#  (384, 9, 382),
#  (385, 6, 11),
#  (385, 9, 34),
#  (-37, 6, 17),
#  (-37, 18, 311),
#  (-37, 24, 327),
#  (385, 9, -37),
#  (386, 6, 11),
#  (386, 9, 385),
#  (387, 6, 11),
#  (387, 9, 385),
#  (388, 6, 11),
#  (388, 9, 389),
#  (-38, 6, 17),
#  (-38, 18, 311),
#  (-38, 24, 329),
#  (388, 9, -38),
#  (-39, 6, 17),
#  (-39, 18, 311),
#  (-39, 24, 390),
#  (388, 9, -39),
#  (391, 6, 11),
#  (391, 9, 34),
#  (-40, 6, 17),
#  (-40, 18, 311),
#  (-40, 24, 392),
#  (391, 9, -40),
#  (391, 304, 393),
#  (394, 6, 11),
#  (394, 9, 391),
#  (-41, 6, 17),
#  (-41, 18, 311),
#  (-41, 24, 395),
#  (394, 9, -41),
#  (396, 6, 11),
#  (396, 9, 394),
#  (396, 9, 397),
#  (398, 6, 11),
#  (398, 9, 394),
#  (399, 6, 11),
#  (399, 9, 394),
#  (400, 6, 11),
#  (400, 9, 391),
#  (401, 6, 11),
#  (401, 9, 391),
#  (-42, 6, 17),
#  (-42, 18, 311),
#  (-42, 24, 402),
#  (401, 9, -42),
#  (403, 6, 11),
#  (403, 9, 401),
#  (404, 6, 11),
#  (404, 9, 401),
#  (404, 9, 405),
#  (406, 6, 11),
#  (406, 9, 401),
#  (407, 6, 11),
#  (407, 9, 401),
#  (408, 6, 11),
#  (408, 9, 401),
#  (409, 6, 11),
#  (409, 9, 34),
#  (-43, 6, 17),
#  (-43, 18, 311),
#  (-43, 24, 410),
#  (409, 9, -43),
#  (-44, 6, 17),
#  (-44, 18, 311),
#  (-44, 24, 329),
#  (409, 9, -44),
#  (411, 6, 11),
#  (411, 9, 34),
#  (-45, 6, 17),
#  (-45, 18, 311),
#  (-45, 24, 409),
#  (411, 9, -45),
#  (412, 6, 11),
#  (412, 9, 411),
#  (413, 6, 11),
#  (413, 9, 411),
#  (414, 6, 11),
#  (414, 9, 415),
#  (-46, 6, 17),
#  (-46, 18, 311),
#  (-46, 24, 409),
#  (414, 9, -46),
#  (416, 6, 11),
#  (416, 9, 414),
#  (-47, 6, 17),
#  (-47, 18, 311),
#  (-47, 24, 411),
#  (416, 9, -47),
#  (417, 6, 11),
#  (417, 9, 34),
#  (-48, 6, 17),
#  (-48, 18, 311),
#  (-48, 24, 414),
#  (417, 9, -48),
#  (418, 6, 11),
#  (418, 9, 414),
#  (-49, 6, 17),
#  (-49, 18, 311),
#  (-49, 24, 419),
#  (418, 9, -49),
#  (420, 6, 11),
#  (420, 9, 421),
#  (-50, 6, 17),
#  (-50, 18, 311),
#  (-50, 24, 409),
#  (420, 9, -50),
#  (422, 6, 11),
#  (422, 9, 420),
#  (-51, 6, 17),
#  (-51, 18, 311),
#  (-51, 24, 411),
#  (422, 9, -51),
#  (423, 6, 11),
#  (423, 9, 420),
#  (-52, 6, 17),
#  (-52, 18, 311),
#  (-52, 24, 419),
#  (423, 9, -52),
#  (424, 6, 11),
#  (424, 9, 34),
#  (-53, 6, 17),
#  (-53, 18, 311),
#  (-53, 24, 409),
#  (424, 9, -53),
#  (425, 6, 11),
#  (425, 9, 424),
#  (425, 304, 426),
#  (427, 6, 11),
#  (427, 9, 424),
#  (427, 304, 428),
#  (429, 6, 11),
#  (429, 9, 34),
#  (-54, 6, 17),
#  (-54, 18, 311),
#  (-54, 24, 409),
#  (429, 9, -54),
#  (430, 6, 11),
#  (430, 9, 429),
#  (431, 6, 11),
#  (431, 9, 429),
#  (431, 304, 432),
#  (433, 6, 11),
#  (433, 9, 429),
#  (434, 6, 11),
#  (434, 9, 429),
#  (419, 6, 11),
#  (419, 9, 34),
#  (-55, 6, 17),
#  (-55, 18, 311),
#  (-55, 24, 409),
#  (419, 9, -55),
#  (435, 6, 11),
#  (435, 9, 419),
#  (436, 6, 11),
#  (436, 9, 419),
#  (437, 6, 11),
#  (437, 9, 34),
#  (-56, 6, 17),
#  (-56, 18, 311),
#  (-56, 24, 409),
#  (437, 9, -56),
#  (438, 6, 11),
#  (438, 9, 34),
#  (-57, 6, 17),
#  (-57, 18, 311),
#  (-57, 24, 437),
#  (438, 9, -57),
#  (438, 304, 439),
#  (440, 6, 11),
#  (440, 9, 34),
#  (-58, 6, 17),
#  (-58, 18, 311),
#  (-58, 24, 437),
#  (440, 9, -58),
#  (441, 6, 11),
#  (441, 9, 34),
#  (-59, 6, 17),
#  (-59, 18, 311),
#  (-59, 24, 437),
#  (441, 9, -59),
#  (441, 304, 442),
#  (443, 6, 11),
#  (443, 9, 34),
#  (-60, 6, 17),
#  (-60, 18, 311),
#  (-60, 24, 409),
#  (443, 9, -60),
#  (444, 6, 11),
#  (444, 9, 445),
#  (-61, 6, 17),
#  (-61, 18, 311),
#  (-61, 24, 381),
#  (444, 9, -61),
#  (-62, 6, 17),
#  (-62, 18, 311),
#  (-62, 24, 410),
#  (444, 9, -62),
#  (446, 6, 11),
#  (446, 9, 34),
#  (-63, 6, 17),
#  (-63, 18, 311),
#  (-63, 24, 409),
#  (446, 9, -63),
#  (447, 6, 11),
#  (447, 9, 34),
#  (-64, 6, 17),
#  (-64, 18, 311),
#  (-64, 24, 446),
#  (447, 9, -64),
#  (448, 6, 11),
#  (448, 9, 34),
#  (-65, 6, 17),
#  (-65, 18, 311),
#  (-65, 24, 446),
#  (448, 9, -65),
#  (449, 6, 11),
#  (449, 9, 34),
#  (-66, 6, 17),
#  (-66, 18, 311),
#  (-66, 24, 446),
#  (449, 9, -66),
#  (450, 6, 11),
#  (450, 9, 328),
#  (451, 6, 11),
#  (451, 9, 450),
#  (452, 6, 11),
#  (452, 9, 450),
#  (453, 6, 11),
#  (453, 9, 450),
#  (454, 6, 11),
#  (454, 9, 450),
#  (455, 6, 11),
#  (455, 9, 450),
#  (456, 6, 11),
#  (456, 9, 328),
#  (-67, 6, 17),
#  (-67, 18, 311),
#  (-67, 24, 457),
#  (456, 9, -67),
#  (458, 6, 11),
#  (458, 9, 34),
#  (-68, 6, 17),
#  (-68, 18, 311),
#  (-68, 24, 456),
#  (458, 9, -68),
#  (459, 6, 11),
#  (459, 9, 34),
#  (-69, 6, 17),
#  (-69, 18, 311),
#  (-69, 24, 456),
#  (459, 9, -69),
#  (460, 6, 11),
#  (460, 9, 328),
#  (461, 6, 11),
#  (461, 9, 328),
#  (462, 6, 11),
#  (462, 9, 328),
#  (463, 6, 11),
#  (463, 9, 464),
#  (463, 9, 465),
#  (463, 304, 466),
#  (467, 6, 11),
#  (467, 9, 34),
#  (-70, 6, 17),
#  (-70, 18, 311),
#  (-70, 24, 463),
#  (467, 9, -70),
#  (468, 6, 11),
#  (468, 9, 34),
#  (-71, 6, 17),
#  (-71, 18, 311),
#  (-71, 24, 463),
#  (468, 9, -71),
#  (469, 6, 11),
#  (469, 9, 34),
#  (-72, 6, 17),
#  (-72, 18, 311),
#  (-72, 24, 463),
#  (469, 9, -72),
#  (470, 6, 11),
#  (470, 9, 464),
#  (471, 6, 11),
#  (471, 9, 34),
#  (-73, 6, 17),
#  (-73, 18, 311),
#  (-73, 24, 470),
#  (471, 9, -73),
#  (471, 304, 472),
#  (473, 6, 11),
#  (473, 9, 34),
#  (-74, 6, 17),
#  (-74, 18, 311),
#  (-74, 24, 470),
#  (473, 9, -74),
#  (474, 6, 11),
#  (474, 9, 34),
#  (-75, 6, 17),
#  (-75, 18, 311),
#  (-75, 24, 470),
#  (474, 9, -75),
#  (475, 6, 11),
#  (475, 9, 34),
#  (-76, 6, 17),
#  (-76, 18, 311),
#  (-76, 24, 476),
#  (475, 9, -76),
#  (477, 6, 11),
#  (477, 9, 475),
#  (478, 6, 11),
#  (478, 9, 475),
#  (479, 6, 11),
#  (479, 9, 34),
#  (-77, 6, 17),
#  (-77, 18, 311),
#  (-77, 24, 480),
#  (479, 9, -77),
#  (479, 304, 481),
#  (482, 6, 11),
#  (482, 9, 483),
#  (482, 9, 465),
#  (484, 6, 11),
#  (484, 9, 483),
#  (484, 9, 465),
#  (485, 6, 11),
#  (485, 9, 34),
#  (-78, 6, 17),
#  (-78, 18, 311),
#  (-78, 24, 484),
#  (485, 9, -78),
#  (486, 6, 11),
#  (486, 9, 34),
#  (-79, 6, 17),
#  (-79, 18, 311),
#  (-79, 24, 484),
#  (486, 9, -79),
#  (487, 6, 11),
#  (487, 9, 34),
#  (-80, 6, 17),
#  (-80, 18, 311),
#  (-80, 24, 484),
#  (487, 9, -80),
#  (488, 6, 11),
#  (488, 9, 34),
#  (-81, 6, 17),
#  (-81, 18, 311),
#  (-81, 24, 489),
#  (488, 9, -81),
#  (488, 304, 490),
#  (491, 6, 11),
#  (491, 9, 34),
#  (-82, 6, 17),
#  (-82, 18, 311),
#  (-82, 24, 492),
#  (491, 9, -82),
#  (-83, 6, 17),
#  (-83, 18, 311),
#  (-83, 24, 390),
#  (491, 9, -83),
#  (-84, 6, 17),
#  (-84, 18, 311),
#  (-84, 24, 493),
#  (491, 9, -84),
#  (494, 6, 11),
#  (494, 9, 34),
#  (-85, 6, 17),
#  (-85, 18, 311),
#  (-85, 24, 495),
#  (494, 9, -85),
#  (494, 304, 496),
#  (497, 6, 11),
#  (497, 9, 34),
#  (-86, 6, 17),
#  (-86, 18, 311),
#  (-86, 24, 495),
#  (497, 9, -86),
#  (497, 304, 498),
#  (499, 6, 11),
#  (499, 9, 497),
#  (-87, 6, 17),
#  (-87, 18, 311),
#  (-87, 24, 500),
#  (499, 9, -87),
#  (501, 6, 11),
#  (501, 9, 34),
#  (-88, 6, 17),
#  (-88, 18, 311),
#  (-88, 24, 392),
#  (501, 9, -88),
#  (-89, 6, 17),
#  (-89, 18, 311),
#  (-89, 24, 502),
#  (501, 9, -89),
#  (503, 6, 11),
#  (503, 9, 34),
#  (-90, 6, 17),
#  (-90, 18, 311),
#  (-90, 24, 502),
#  (503, 9, -90),
#  (504, 6, 11),
#  (504, 9, 34),
#  (-91, 6, 17),
#  (-91, 18, 311),
#  (-91, 24, 495),
#  (504, 9, -91),
#  (504, 304, 505),
#  (506, 6, 11),
#  (506, 9, 464),
#  (-92, 6, 17),
#  (-92, 18, 311),
#  (-92, 24, 390),
#  (506, 9, -92),
#  (-93, 6, 17),
#  (-93, 18, 311),
#  (-93, 24, 492),
#  (506, 9, -93),
#  (507, 6, 11),
#  (507, 9, 508),
#  (-94, 6, 17),
#  (-94, 18, 311),
#  (-94, 24, 492),
#  (507, 9, -94),
#  (-95, 6, 17),
#  (-95, 18, 311),
#  (-95, 24, 390),
#  (507, 9, -95),
#  (509, 6, 11),
#  (509, 9, 510),
#  (-96, 6, 17),
#  (-96, 18, 311),
#  (-96, 24, 511),
#  (509, 9, -96),
#  (512, 6, 11),
#  (512, 9, 34),
#  (-97, 6, 17),
#  (-97, 18, 311),
#  (-97, 24, 334),
#  (512, 9, -97),
#  (513, 6, 11),
#  (513, 9, 512),
#  (513, 9, 514),
#  (515, 6, 11),
#  (515, 9, 512),
#  (-98, 6, 17),
#  (-98, 18, 311),
#  (-98, 24, 516),
#  (515, 9, -98),
#  (517, 6, 11),
#  (517, 9, 515),
#  (518, 6, 11),
#  (518, 9, 515),
#  (519, 6, 11),
#  (519, 9, 515),
#  (519, 9, 520),
#  (521, 6, 11),
#  (521, 9, 515),
#  (521, 9, 514),
#  (516, 6, 11),
#  (516, 9, 34),
#  (-99, 6, 17),
#  (-99, 18, 311),
#  (-99, 24, 334),
#  (516, 9, -99),
#  (522, 6, 11),
#  (522, 9, 34),
#  (-100, 6, 17),
#  (-100, 18, 311),
#  (-100, 24, 516),
#  (522, 9, -100),
#  (523, 6, 11),
#  (523, 9, 34),
#  (-101, 6, 17),
#  (-101, 18, 311),
#  (-101, 24, 516),
#  (523, 9, -101),
#  (524, 6, 11),
#  (524, 9, 34),
#  (-102, 6, 17),
#  (-102, 18, 311),
#  (-102, 24, 334),
#  (524, 9, -102),
#  (525, 6, 11),
#  (525, 9, 34),
#  (-103, 6, 17),
#  (-103, 18, 311),
#  (-103, 24, 334),
#  (525, 9, -103),
#  (526, 6, 11),
#  (526, 9, 34),
#  (-104, 6, 17),
#  (-104, 18, 311),
#  (-104, 24, 525),
#  (526, 9, -104),
#  (527, 6, 11),
#  (527, 9, 34),
#  (-105, 6, 17),
#  (-105, 18, 311),
#  (-105, 24, 525),
#  (527, 9, -105),
#  (528, 6, 11),
#  (528, 9, 34),
#  (-106, 6, 17),
#  (-106, 18, 311),
#  (-106, 24, 525),
#  (528, 9, -106),
#  (529, 6, 11),
#  (529, 9, 34),
#  (-107, 6, 17),
#  (-107, 18, 311),
#  (-107, 24, 530),
#  (529, 9, -107),
#  (-108, 6, 17),
#  (-108, 18, 311),
#  (-108, 24, 525),
#  (529, 9, -108),
#  (530, 6, 11),
#  (530, 9, 524),
#  (531, 6, 11),
#  (531, 9, 34),
#  (-109, 6, 17),
#  (-109, 18, 311),
#  (-109, 24, 530),
#  (531, 9, -109),
#  (532, 6, 11),
#  (532, 9, 34),
#  (-110, 6, 17),
#  (-110, 18, 311),
#  (-110, 24, 531),
#  (532, 9, -110),
#  (533, 6, 11),
#  (533, 9, 34),
#  (-111, 6, 17),
#  (-111, 18, 311),
#  (-111, 24, 334),
#  (533, 9, -111),
#  (533, 304, 534),
#  (421, 6, 11),
#  (421, 9, 335),
#  (421, 304, 535),
#  (536, 6, 11),
#  (536, 9, 335),
#  (537, 6, 11),
#  (537, 9, 335),
#  (538, 6, 11),
#  (538, 9, 34),
#  (-112, 6, 17),
#  (-112, 18, 311),
#  (-112, 24, 337),
#  (538, 9, -112),
#  (539, 6, 11),
#  (539, 9, 540),
#  (-113, 6, 17),
#  (-113, 18, 311),
#  (-113, 24, 538),
#  (539, 9, -113),
#  (541, 6, 11),
#  (541, 9, 34),
#  (-114, 6, 17),
#  (-114, 18, 311),
#  (-114, 24, 539),
#  (541, 9, -114),
#  (541, 304, 542),
#  (543, 6, 11),
#  (543, 9, 34),
#  (-115, 6, 17),
#  (-115, 18, 311),
#  (-115, 24, 539),
#  (543, 9, -115),
#  (543, 304, 544),
#  (545, 6, 11),
#  (545, 9, 34),
#  (-116, 6, 17),
#  (-116, 18, 311),
#  (-116, 24, 543),
#  (545, 9, -116),
#  (546, 6, 11),
#  (546, 9, 34),
#  (-117, 6, 17),
#  (-117, 18, 311),
#  (-117, 24, 545),
#  (546, 9, -117),
#  (547, 6, 11),
#  (547, 9, 34),
#  (-118, 6, 17),
#  (-118, 18, 311),
#  (-118, 24, 545),
#  (547, 9, -118),
#  (548, 6, 11),
#  (548, 9, 34),
#  (-119, 6, 17),
#  (-119, 18, 311),
#  (-119, 24, 545),
#  (548, 9, -119),
#  (549, 6, 11),
#  (549, 9, 550),
#  (-120, 6, 17),
#  (-120, 18, 311),
#  (-120, 24, 545),
#  (549, 9, -120),
#  (549, 304, 551),
#  (549, 304, 552),
#  (553, 6, 11),
#  (553, 9, 550),
#  (-121, 6, 17),
#  (-121, 18, 311),
#  (-121, 24, 545),
#  (553, 9, -121),
#  (553, 304, 554),
#  (555, 6, 11),
#  (555, 9, 34),
#  (-122, 6, 17),
#  (-122, 18, 311),
#  (-122, 24, 553),
#  (555, 9, -122),
#  (556, 6, 11),
#  (556, 9, 34),
#  (-123, 6, 17),
#  (-123, 18, 311),
#  (-123, 24, 553),
#  (556, 9, -123),
#  (557, 6, 11),
#  (557, 9, 34),
#  (-124, 6, 17),
#  (-124, 18, 311),
#  (-124, 24, 545),
#  (557, 9, -124),
#  (558, 6, 11),
#  (558, 9, 34),
#  (-125, 6, 17),
#  (-125, 18, 311),
#  (-125, 24, 557),
#  (558, 9, -125),
#  (559, 6, 11),
#  (559, 9, 34),
#  (-126, 6, 17),
#  (-126, 18, 311),
#  (-126, 24, 557),
#  (559, 9, -126),
#  (559, 304, 560),
#  (561, 6, 11),
#  (561, 9, 562),
#  (-127, 6, 17),
#  (-127, 18, 311),
#  (-127, 24, 545),
#  (561, 9, -127),
#  (561, 304, 563),
#  (489, 6, 11),
#  (489, 9, 34),
#  (-128, 6, 17),
#  (-128, 18, 311),
#  (-128, 24, 543),
#  (489, 9, -128),
#  (489, 304, 564),
#  (489, 304, 565),
#  (566, 6, 11),
#  (566, 9, 34),
#  (-129, 6, 17),
#  (-129, 18, 311),
#  (-129, 24, 489),
#  (566, 9, -129),
#  (566, 304, 567),
#  (568, 6, 11),
#  (568, 9, 34),
#  (-130, 6, 17),
#  (-130, 18, 311),
#  (-130, 24, 488),
#  (568, 9, -130),
#  (569, 6, 11),
#  (569, 9, 34),
#  (-131, 6, 17),
#  (-131, 18, 311),
#  (-131, 24, 570),
#  (569, 9, -131),
#  (569, 304, 571),
#  (572, 6, 11),
#  (572, 9, 34),
#  (-132, 6, 17),
#  (-132, 18, 311),
#  (-132, 24, 570),
#  (572, 9, -132),
#  (572, 304, 573),
#  (574, 6, 11),
#  (574, 9, 575),
#  (576, 6, 11),
#  (576, 9, 34),
#  (-133, 6, 17),
#  (-133, 18, 311),
#  (-133, 24, 489),
#  (576, 9, -133),
#  (576, 304, 577),
#  (576, 304, 578),
#  (579, 6, 11),
#  (579, 9, 34),
#  (-134, 6, 17),
#  (-134, 18, 311),
#  (-134, 24, 576),
#  (579, 9, -134),
#  (580, 6, 11),
#  (580, 9, 34),
#  (-135, 6, 17),
#  (-135, 18, 311),
#  (-135, 24, 576),
#  (580, 9, -135),
#  (580, 304, 581),
#  (582, 6, 11),
#  (582, 9, 562),
#  (-136, 6, 17),
#  (-136, 18, 311),
#  (-136, 24, 489),
#  (582, 9, -136),
#  (583, 6, 11),
#  (583, 9, 34),
#  (-137, 6, 17),
#  (-137, 18, 311),
#  (-137, 24, 584),
#  (583, 9, -137),
#  (583, 304, 585),
#  (586, 6, 11),
#  (586, 9, 34),
#  (-138, 6, 17),
#  (-138, 18, 311),
#  (-138, 24, 584),
#  (586, 9, -138),
#  (586, 304, 587),
#  (588, 6, 11),
#  (588, 9, 34),
#  ...]

# %%
from collections import defaultdict
import itertools

def build_inverted_index(ontology, external_lexicon=None):
    if ontology is None:
        raise ValueError("Ontology is not loaded!")

    index = defaultdict(set)  # Key: frozenset of normalized terms, Value: set of class IDs
    class_id_map = {}         # Map class URIs to numerical IDs
    current_id = 0

    # Assign numerical IDs to classes
    for cls in ontology.classes():
        class_id_map[cls.iri] = current_id
        current_id += 1

    for cls in ontology.classes():
        cls_id = class_id_map[cls.iri]
        labels = cls.label if hasattr(cls, 'label') else []  # Get all labels

        # Process all labels (primary + synonyms)
        for label in labels:
            # Split into components (e.g., "cellular_secretion" → ["cellular", "secretion"])
            components = label.lower().replace('_', ' ').split()
            
            # Add base terms
            term_set = frozenset(components)
            index[term_set].add(cls_id)

            # Add variations from external lexicon (e.g., "secrete" for "secretion")
            if external_lexicon:
                variations = set()
                for term in components:
                    variations.update(external_lexicon.get_variations(term))  # Hypothetical lexicon method
                if variations:
                    expanded_terms = components + list(variations)
                    term_set_variations = frozenset(expanded_terms)
                    index[term_set_variations].add(cls_id)

    return index, class_id_map

source_index = build_inverted_index(source_ontology.ontology)
target_index = build_inverted_index(target_ontology.ontology)

# %%
print(source_index)
print(target_index)
# Out:
# (defaultdict(<class 'set'>, {frozenset({'mouse', 'anatomy'}): {1}, frozenset({'grey', 'spinal', 'cord', 'matter'}): {2}, frozenset({'grey', 'matter'}): {3}, frozenset({'spinal', 'cord'}): {4}, frozenset({'organ', 'system'}): {5}, frozenset({'adult', 'mouse'}): {6}, frozenset({'trunk'}): {7}, frozenset({'anatomic', 'region'}): {8}, frozenset({'body', 'cavity/lining'}): {9}, frozenset({'head/neck'}): {10}, frozenset({'limb'}): {11}, frozenset({'tail'}): {12}, frozenset({'adipose', 'tissue'}): {13}, frozenset({'tissue', 'connective'}): {14}, frozenset({'system', 'cardiovascular'}): {15}, frozenset({'system', 'endocrine'}): {16}, frozenset({'system', 'hemolymphoid'}): {17}, frozenset({'system', 'integumental'}): {18}, frozenset({'muscle'}): {19}, frozenset({'system', 'musculoskeletal'}): {20}, frozenset({'system', 'nervous'}): {21}, frozenset({'organ', 'sensory'}): {22}, frozenset({'organ', 'sensory', 'system'}): {23}, frozenset({'system', 'skeletal'}): {24}, frozenset({'organ', 'visceral', 'system'}): {25}, frozenset({'back'}): {26}, frozenset({'abdomen/pelvis/perineum'}): {27}, frozenset({'thorax'}): {28}, frozenset({'head'}): {29}, frozenset({'neck'}): {30}, frozenset({'forelimb'}): {31}, frozenset({'hindlimb'}): {32}, frozenset({'back', 'lower'}): {33}, frozenset({'back', 'upper'}): {34}, frozenset({'abdomen'}): {35}, frozenset({'pelvis'}): {36}, frozenset({'chest'}): {37}, frozenset({'thoracic', 'cavity'}): {38}, frozenset({'arm'}): {39}, frozenset({'arm', 'lower'}): {40}, frozenset({'arm', 'upper'}): {41}, frozenset({'elbow'}): {42}, frozenset({'hand'}): {43}, frozenset({'autopod'}): {44}, frozenset({'shoulder'}): {45}, frozenset({'wrist'}): {46}, frozenset({'carpus'}): {47}, frozenset({'digit', 'hand'}): {48}, frozenset({'digit', 'limb'}): {49}, frozenset({'metacarpus'}): {50}, frozenset({'ankle'}): {51}, frozenset({'foot'}): {52}, frozenset({'hip'}): {53}, frozenset({'knee'}): {54}, frozenset({'leg'}): {55}, frozenset({'foot', 'digit'}): {56}, frozenset({'metatarsus'}): {57}, frozenset({'tarsus'}): {58}, frozenset({'lower', 'leg'}): {59}, frozenset({'upper', 'leg'}): {60}, frozenset({'pericardial', 'cavity'}): {61}, frozenset({'body', 'cavity'}): {62}, frozenset({'peritoneal', 'cavity'}): {63}, frozenset({'pleural', 'cavity'}): {64}, frozenset({'fat'}): {65}, frozenset({'brown', 'fat'}): {66}, frozenset({'fat', 'white'}): {67}, frozenset({'blood'}): {68}, frozenset({'fluid/substance', 'body'}): {69}, frozenset({'hematopoietic', 'system'}): {70}, frozenset({'vessel', 'blood'}): {71}, frozenset({'system', 'vascular'}): {72}, frozenset({'blood', 'arterial', 'vessel'}): {73}, frozenset({'system', 'arterial'}): {74}, frozenset({'aorta'}): {75}, frozenset({'artery', 'thoracic', 'cavity'}): {76}, frozenset({'arteriole'}): {77}, frozenset({'artery'}): {78}, frozenset({'capillary'}): {79}, frozenset({'venous', 'blood', 'vessel'}): {80}, frozenset({'venous', 'system'}): {81}, frozenset({'vein'}): {82}, frozenset({'vena', 'cava'}): {83}, frozenset({'vein', 'thoracic', 'cavity'}): {84}, frozenset({'plexus', 'venous'}): {85}, frozenset({'venous', 'sinus'}): {86}, frozenset({'venule'}): {87}, frozenset({'heart'}): {88}, frozenset({'heart/pericardium'}): {89}, frozenset({'heart', 'atrium'}): {90}, frozenset({'heart', 'left', 'atrium'}): {91}, frozenset({'heart', 'right', 'atrium'}): {92}, frozenset({'endocardium', 'heart'}): {93}, frozenset({'endothelium', 'system', 'cardiovascular'}): {94}, frozenset({'endocardium', 'atrium'}): {95}, frozenset({'cushion', 'endocardial'}): {96}, frozenset({'endocardium', 'ventricle'}): {97}, frozenset({'heart', 'ventricle'}): {98}, frozenset({'heart', 'myocardium'}): {99}, frozenset({'myocardium'}): {100}, frozenset({'myocardium', 'atrium'}): {101}, frozenset({'ventricle', 'myocardium'}): {102}, frozenset({'heart', 'septum'}): {103}, frozenset({'atrial', 'septum'}): {104}, frozenset({'septum', 'ventricular'}): {105}, frozenset({'valve', 'heart'}): {106}, frozenset({'valve', 'aortic'}): {107}, frozenset({ ...
# (defaultdict(<class 'set'>, {frozenset({'or', 'anatomic', 'structure', 'system', 'substance'}): {6}, frozenset({'lip'}): {7}, frozenset({'neck', 'and', 'head', 'part'}): {8}, frozenset({'head'}): {9}, frozenset({'lip', 'external', 'upper'}): {10}, frozenset({'external', 'lip'}): {11}, frozenset({'lip', 'external', 'lower'}): {12}, frozenset({'the', 'lip', 'upper', 'of', 'mucosa'}): {13}, frozenset({'the', 'of', 'mucosa', 'lip'}): {14}, frozenset({'the', 'lower', 'lip', 'of', 'mucosa'}): {15}, frozenset({'mucosa'}): {16}, frozenset({'the', 'of', 'lip', 'commissure'}): {17}, frozenset({'tongue', 'the', 'of', 'base'}): {18}, frozenset({'organ', 'part', 'special', 'of', 'sense'}): {19}, frozenset({'tongue'}): {20}, frozenset({'palate'}): {21}, frozenset({'oral', 'cavity'}): {22}, frozenset({'hard', 'palate'}): {23}, frozenset({'palate', 'soft'}): {24}, frozenset({'uvula'}): {25}, frozenset({'submandibular', 'gland'}): {26}, frozenset({'major', 'salivary', 'gland'}): {27}, frozenset({'sublingual', 'salivary', 'gland'}): {28}, frozenset({'tonsillar', 'fossa'}): {29}, frozenset({'fossa'}): {30}, frozenset({'part', 'tonsil'}): {31}, frozenset({'tonsil'}): {32}, frozenset({'pillar', 'tonsillar'}): {33}, frozenset({'vallecula'}): {34}, frozenset({'brain', 'part'}): {35}, frozenset({'the', 'cerebellum', 'of', 'hemisphere'}): {36}, frozenset({'the', 'anterior', 'epiglottis', 'surface', 'of'}): {37}, frozenset({'anatomic', 'surface'}): {38}, frozenset({'epiglottis'}): {39}, frozenset({'the', 'wall', 'lateral', 'of', 'oropharynx'}): {40}, frozenset({'oropharynx'}): {41}, frozenset({'the', 'posterior', 'wall', 'of', 'oropharynx'}): {42}, frozenset({'the', 'wall', 'nasopharynx', 'superior', 'of'}): {43}, frozenset({'nasopharynx'}): {44}, frozenset({'the', 'posterior', 'wall', 'nasopharynx', 'of'}): {45}, frozenset({'the', 'wall', 'lateral', 'nasopharynx', 'of'}): {46}, frozenset({'the', 'wall', 'anterior', 'nasopharynx', 'of'}): {47}, frozenset({'hypopharynx'}): {48}, frozenset({'pharynx'}): {49}, frozenset({'the', 'posterior', 'hypopharynx', 'wall', 'of'}): {50}, frozenset({'esophagus', 'cervical'}): {51}, frozenset({'body', 'region'}): {52}, frozenset({'esophagus'}): {53}, frozenset({'esophagus', 'thoracic'}): {54}, frozenset({'esophagus', 'abdominal'}): {55}, frozenset({'abdominal', 'cavity'}): {56}, frozenset({'the', 'upper', 'of', 'esophagus', 'third'}): {57}, frozenset({'the', 'of', 'esophagus', 'third', 'middle'}): {58}, frozenset({'the', 'lower', 'of', 'esophagus', 'third'}): {59}, frozenset({'cardia'}): {60}, frozenset({'part', 'system', 'gastrointestinal'}): {61}, frozenset({'stomach'}): {62}, frozenset({'of', 'fundus', 'stomach', 'the'}): {63}, frozenset({'stomach', 'body', 'of'}): {64}, frozenset({'antrum', 'pylori'}): {65}, frozenset({'pylorus'}): {66}, frozenset({'curvature', 'lesser'}): {67}, frozenset({'greater', 'curvature'}): {68}, frozenset({'duodenum'}): {69}, frozenset({'epigastric', 'region'}): {70}, frozenset({'small', 'intestine'}): {71}, frozenset({'colon', 'ascending'}): {72}, frozenset({'right', 'lumbar', 'region'}): {73}, frozenset({'colon'}): {74}, frozenset({'hepatic', 'flexure'}): {75}, frozenset({'right', 'region', 'hypochondriac'}): {76}, frozenset({'splenic', 'flexure'}): {77}, frozenset({'region', 'hypochondriac', 'left'}): {78}, frozenset({'colon', 'descending'}): {79}, frozenset({'lumbar', 'region', 'left'}): {80}, frozenset({'the', 'head', 'of', 'pancreas'}): {81}, frozenset({'pancreas'}): {82}, frozenset({'the', 'body', 'of', 'pancreas'}): {83}, frozenset({'the', 'tail', 'of', 'pancreas'}): {84}, frozenset({'pancreatic', 'duct'}): {85}, frozenset({'duct'}): {86}, frozenset({'exocrine', 'pancreas'}): {87}, frozenset({'pancreas', 'other', 'parts', 'specified', 'of'}): {88}, frozenset({'anatomic', 'concept', 'other'}): {89}, frozenset({'middle', 'ear'}): {90}, frozenset({'part', 'ear'}): {91}, frozenset({'ear'}): {92}, frozenset({'sinus', 'maxillary'}): {93}, frozenset({'paranasal', 'sinus'}): {94}, frozens ...

# %%
source_index[0].keys()
# Out:
# dict_keys([frozenset({'mouse', 'anatomy'}), frozenset({'matter', 'spinal', 'grey', 'cord'}), frozenset({'matter', 'grey'}), frozenset({'spinal', 'cord'}), frozenset({'system', 'organ'}), frozenset({'adult', 'mouse'}), frozenset({'trunk'}), frozenset({'region', 'anatomic'}), frozenset({'body', 'cavity/lining'}), frozenset({'head/neck'}), frozenset({'limb'}), frozenset({'tail'}), frozenset({'tissue', 'adipose'}), frozenset({'connective', 'tissue'}), frozenset({'cardiovascular', 'system'}), frozenset({'system', 'endocrine'}), frozenset({'system', 'hemolymphoid'}), frozenset({'system', 'integumental'}), frozenset({'muscle'}), frozenset({'system', 'musculoskeletal'}), frozenset({'nervous', 'system'}), frozenset({'organ', 'sensory'}), frozenset({'system', 'organ', 'sensory'}), frozenset({'system', 'skeletal'}), frozenset({'organ', 'system', 'visceral'}), frozenset({'back'}), frozenset({'abdomen/pelvis/perineum'}), frozenset({'thorax'}), frozenset({'head'}), frozenset({'neck'}), frozenset({'forelimb'}), frozenset({'hindlimb'}), frozenset({'back', 'lower'}), frozenset({'back', 'upper'}), frozenset({'abdomen'}), frozenset({'pelvis'}), frozenset({'chest'}), frozenset({'cavity', 'thoracic'}), frozenset({'arm'}), frozenset({'lower', 'arm'}), frozenset({'upper', 'arm'}), frozenset({'elbow'}), frozenset({'hand'}), frozenset({'autopod'}), frozenset({'shoulder'}), frozenset({'wrist'}), frozenset({'carpus'}), frozenset({'digit', 'hand'}), frozenset({'digit', 'limb'}), frozenset({'metacarpus'}), frozenset({'ankle'}), frozenset({'foot'}), frozenset({'hip'}), frozenset({'knee'}), frozenset({'leg'}), frozenset({'foot', 'digit'}), frozenset({'metatarsus'}), frozenset({'tarsus'}), frozenset({'lower', 'leg'}), frozenset({'upper', 'leg'}), frozenset({'pericardial', 'cavity'}), frozenset({'cavity', 'body'}), frozenset({'cavity', 'peritoneal'}), frozenset({'cavity', 'pleural'}), frozenset({'fat'}), frozenset({'brown', 'fat'}), frozenset({'fat', 'white'}), frozenset({'blood'}), frozenset({'fluid/substance', 'body'}), frozenset({'system', 'hematopoietic'}), frozenset({'vessel', 'blood'}), frozenset({'vascular', 'system'}), frozenset({'blood', 'vessel', 'arterial'}), frozenset({'system', 'arterial'}), frozenset({'aorta'}), frozenset({'cavity', 'artery', 'thoracic'}), frozenset({'arteriole'}), frozenset({'artery'}), frozenset({'capillary'}), frozenset({'venous', 'vessel', 'blood'}), frozenset({'venous', 'system'}), frozenset({'vein'}), frozenset({'cava', 'vena'}), frozenset({'cavity', 'vein', 'thoracic'}), frozenset({'venous', 'plexus'}), frozenset({'venous', 'sinus'}), frozenset({'venule'}), frozenset({'heart'}), frozenset({'heart/pericardium'}), frozenset({'heart', 'atrium'}), frozenset({'heart', 'atrium', 'left'}), frozenset({'heart', 'right', 'atrium'}), frozenset({'heart', 'endocardium'}), frozenset({'cardiovascular', 'system', 'endothelium'}), frozenset({'endocardium', 'atrium'}), frozenset({'cushion', 'endocardial'}), frozenset({'endocardium', 'ventricle'}), frozenset({'heart', 'ventricle'}), frozenset({'heart', 'myocardium'}), frozenset({'myocardium'}), frozenset({'myocardium', 'atrium'}), frozenset({'myocardium', 'ventricle'}), frozenset({'heart', 'septum'}), frozenset({'septum', 'atrial'}), frozenset({'septum', 'ventricular'}), frozenset({'heart', 'valve'}), frozenset({'aortic', 'valve'}), frozenset({'mitral', 'valve'}), frozenset({'pulmonary', 'valve'}), frozenset({'tricuspid', 'valve'}), frozenset({'heart', 'ventricle', 'left'}), frozenset({'heart', 'right', 'ventricle'}), frozenset({'system', 'conducting', 'impulse'}), frozenset({'atrioventricular', 'node'}), frozenset({'purkinje', 'fiber'}), frozenset({'node', 'sinoatrial'}), frozenset({'mesocardium'}), frozenset({'pericardium'}), frozenset({'cavity', 'lining'}), frozenset({'outflow', 'tract'}), frozenset({'aortic', 'outflow', 'tract', 'component'}), frozenset({'outflow', 'pulmonary', 'tract', 'component'}), frozenset({'arteriosus', 'truncus'}), frozenset({'cartilage'}), frozenset({'cartilage' ...

# %%
source_index[1].keys()
# Out:
# dict_keys(['http://www.w3.org/2002/07/owl#Thing', 'http://mouse.owl#MA_0000001', 'http://mouse.owl#MA_0000002', 'http://mouse.owl#MA_0001112', 'http://mouse.owl#MA_0000216', 'http://mouse.owl#MA_0000003', 'http://mouse.owl#MA_0002405', 'http://mouse.owl#MA_0000004', 'http://mouse.owl#MA_0002433', 'http://mouse.owl#MA_0000005', 'http://mouse.owl#MA_0000006', 'http://mouse.owl#MA_0000007', 'http://mouse.owl#MA_0000008', 'http://mouse.owl#MA_0000009', 'http://mouse.owl#MA_0000011', 'http://mouse.owl#MA_0000010', 'http://mouse.owl#MA_0000012', 'http://mouse.owl#MA_0000013', 'http://mouse.owl#MA_0000014', 'http://mouse.owl#MA_0000015', 'http://mouse.owl#MA_0002418', 'http://mouse.owl#MA_0000016', 'http://mouse.owl#MA_0000017', 'http://mouse.owl#MA_0002442', 'http://mouse.owl#MA_0000018', 'http://mouse.owl#MA_0000019', 'http://mouse.owl#MA_0000020', 'http://mouse.owl#MA_0000021', 'http://mouse.owl#MA_0000022', 'http://mouse.owl#MA_0000023', 'http://mouse.owl#MA_0000024', 'http://mouse.owl#MA_0000025', 'http://mouse.owl#MA_0000026', 'http://mouse.owl#MA_0000027', 'http://mouse.owl#MA_0000028', 'http://mouse.owl#MA_0000029', 'http://mouse.owl#MA_0000030', 'http://mouse.owl#MA_0000031', 'http://mouse.owl#MA_0000032', 'http://mouse.owl#MA_0000033', 'http://mouse.owl#MA_0000034', 'http://mouse.owl#MA_0000035', 'http://mouse.owl#MA_0000036', 'http://mouse.owl#MA_0000037', 'http://mouse.owl#MA_0002714', 'http://mouse.owl#MA_0000038', 'http://mouse.owl#MA_0000039', 'http://mouse.owl#MA_0000040', 'http://mouse.owl#MA_0000041', 'http://mouse.owl#MA_0000690', 'http://mouse.owl#MA_0000042', 'http://mouse.owl#MA_0000043', 'http://mouse.owl#MA_0000044', 'http://mouse.owl#MA_0000045', 'http://mouse.owl#MA_0000046', 'http://mouse.owl#MA_0000047', 'http://mouse.owl#MA_0000048', 'http://mouse.owl#MA_0000049', 'http://mouse.owl#MA_0000050', 'http://mouse.owl#MA_0000051', 'http://mouse.owl#MA_0000052', 'http://mouse.owl#MA_0000053', 'http://mouse.owl#MA_0002447', 'http://mouse.owl#MA_0000054', 'http://mouse.owl#MA_0000055', 'http://mouse.owl#MA_0000056', 'http://mouse.owl#MA_0000057', 'http://mouse.owl#MA_0000058', 'http://mouse.owl#MA_0000059', 'http://mouse.owl#MA_0002450', 'http://mouse.owl#MA_0002434', 'http://mouse.owl#MA_0000060', 'http://mouse.owl#MA_0002718', 'http://mouse.owl#MA_0000061', 'http://mouse.owl#MA_0002719', 'http://mouse.owl#MA_0000062', 'http://mouse.owl#MA_0001902', 'http://mouse.owl#MA_0000063', 'http://mouse.owl#MA_0000064', 'http://mouse.owl#MA_0000065', 'http://mouse.owl#MA_0000066', 'http://mouse.owl#MA_0002720', 'http://mouse.owl#MA_0000067', 'http://mouse.owl#MA_0000068', 'http://mouse.owl#MA_0001903', 'http://mouse.owl#MA_0000069', 'http://mouse.owl#MA_0000070', 'http://mouse.owl#MA_0000071', 'http://mouse.owl#MA_0000072', 'http://mouse.owl#MA_0002449', 'http://mouse.owl#MA_0000073', 'http://mouse.owl#MA_0000074', 'http://mouse.owl#MA_0000075', 'http://mouse.owl#MA_0000076', 'http://mouse.owl#MA_0000717', 'http://mouse.owl#MA_0000077', 'http://mouse.owl#MA_0000078', 'http://mouse.owl#MA_0000079', 'http://mouse.owl#MA_0000091', 'http://mouse.owl#MA_0000080', 'http://mouse.owl#MA_0000164', 'http://mouse.owl#MA_0000081', 'http://mouse.owl#MA_0000082', 'http://mouse.owl#MA_0000083', 'http://mouse.owl#MA_0000084', 'http://mouse.owl#MA_0000085', 'http://mouse.owl#MA_0000086', 'http://mouse.owl#MA_0000087', 'http://mouse.owl#MA_0000088', 'http://mouse.owl#MA_0000089', 'http://mouse.owl#MA_0000090', 'http://mouse.owl#MA_0000092', 'http://mouse.owl#MA_0000093', 'http://mouse.owl#MA_0000094', 'http://mouse.owl#MA_0000095', 'http://mouse.owl#MA_0000096', 'http://mouse.owl#MA_0000097', 'http://mouse.owl#MA_0000098', 'http://mouse.owl#MA_0000099', 'http://mouse.owl#MA_0002448', 'http://mouse.owl#MA_0000100', 'http://mouse.owl#MA_0000101', 'http://mouse.owl#MA_0000102', 'http://mouse.owl#MA_0000103', 'http://mouse.owl#MA_0000104', 'http://mouse.owl#MA_0000105', 'http://mouse.owl#MA_0000106', 'http://mouse.owl#MA_0000107', 'http://mouse ...

# %% [markdown]
# ISUB Implementation

# %%
def longest_common_substring(s, t):
    """Find the longest common substring between s and t.
    Returns a tuple (lcs, pos_s, pos_t) where lcs is the substring and
    pos_s, pos_t are its start positions in s and t respectively.
    """
    m, n = len(s), len(t)
    dp = [[0] * (n + 1) for _ in range(m + 1)]
    longest = 0
    pos_s = 0
    pos_t = 0
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if s[i - 1] == t[j - 1]:
                dp[i][j] = dp[i - 1][j - 1] + 1
                if dp[i][j] > longest:
                    longest = dp[i][j]
                    pos_s = i - longest
                    pos_t = j - longest
            else:
                dp[i][j] = 0
    lcs = s[pos_s:pos_s + longest] if longest > 0 else ""
    return lcs, pos_s, pos_t

def _isub_common(s, t):
    """Recursively compute the common part between s and t.
    This function finds the longest common substring and then recurses on
    the parts before and after it. It also adds a bonus for a common prefix.
    """
    # Compute common prefix length (max 4) and bonus factor (0.1 per char)
    prefix = 0
    for i in range(min(len(s), len(t))):
        if s[i] == t[i]:
            prefix += 1
        else:
            break
    prefix = min(prefix, 4)
    prefix_bonus = prefix * 0.1

    lcs, pos_s, pos_t = longest_common_substring(s, t)
    if not lcs:
        return prefix_bonus

    # Recursively process the substrings to the left and right of the LCS
    left_common = _isub_common(s[:pos_s], t[:pos_t])
    right_common = _isub_common(s[pos_s + len(lcs):], t[pos_t + len(lcs):])
    return len(lcs) + left_common + right_common + prefix_bonus

def isub(s, t):
    """
    Compute the ISUB similarity between strings s and t.
    The similarity is given by:
       score = min( 2 * common / (len(s) + len(t)), 1 )
    where 'common' is computed recursively from the longest common substrings
    and includes a bonus for matching prefixes.
    """
    s = s.lower().strip()
    t = t.lower().strip()
    # Handle empty strings: if both are empty, we consider them identical.
    if not s and not t:
        return 1.0
    common = _isub_common(s, t)
    score = 2 * common / (len(s) + len(t))
    return min(score, 1.0)

# alternative implementation
from difflib import SequenceMatcher

def isub_similarity(str1, str2):
    """Compute similarity score between two strings using ISUB (SequenceMatcher)."""
    return SequenceMatcher(None, str1, str2).ratio()

# %%
# Example usage:
if __name__ == "__main__":
    examples = [
        ("CellularSecretion", "cellular secretion"),
        ("Trapezoid", "TrapezoidBone"),
        ("ExocrineGlandFluid", "ExocrineGlandFluid")
    ]
    for a, b in examples:
        print(f"ISUB('{a}', '{b}') = {isub(a, b):.4f}")
# Out:
# ISUB('CellularSecretion', 'cellular secretion') = 1.0000
# ISUB('Trapezoid', 'TrapezoidBone') = 0.8545
# ISUB('ExocrineGlandFluid', 'ExocrineGlandFluid') = 1.0000

# %%
a = set("skeletal muscle")
b = set("Muscle")

intersection = len(a & b)
union = len(a | b)
print(intersection / union if union > 0 else 0.0)
# Out:
# 0.45454545454545453

# %%
print(a)
# Out:
# {' ', 'a', 's', 'u', 't', 'c', 'l', 'm', 'e', 'k'}

# %%
from itertools import product
import re

def get_local_name(entity):
    """
    Extract a local name from an entity's IRI.
    For example, 'source.xml.MA_0000165' becomes 'MA_0000165'.
    """
    iri_str = str(entity)
    parts = iri_str.split('.')
    return parts[-1] if parts else iri_str

def compute_anchors(index1, index2, ontology1, ontology2, isub_threshold=0.8):
    """
    Compute initial anchor mappings between two ontologies.
    """
    anchors = {}
    
    # Step 1: Find common term sets between the inverted indexes
    common_term_sets = set(index1.keys()) & set(index2.keys())
    
    # Convert ontology classes to lists for indexing
    ontology1_list = list(ontology1.classes())
    ontology2_list = list(ontology2.classes())
    
    for term_set in common_term_sets:
        # Get class IDs for this term set from both indexes
        classes1 = index1[term_set]
        classes2 = index2[term_set]
        
        # Step 2: Generate candidate pairs and compute ISUB similarity
        for c1_id, c2_id in product(classes1, classes2):
            c1_uri = ontology1_list[c1_id].iri  # Get class URI from ID
            c2_uri = ontology2_list[c2_id].iri
            
            # Get labels for ISUB similarity
            c1_label = ontology1_list[c1_id].label[0] if ontology1_list[c1_id].label else ""
            c2_label = ontology2_list[c2_id].label[0] if ontology2_list[c2_id].label else ""
            
            similarity = isub_similarity(c1_label, c2_label)  # Use ISUB algorithm
            # print(c1_label, c2_label, similarity)
            
            # Step 3: Check if similarity meets the threshold
            if similarity >= isub_threshold:
                # Step 4: Compute structural confidence (optional for initial anchors)
                confidence = compute_structural_confidence(
                    ontology1_list[c1_id], ontology2_list[c2_id], ontology1, ontology2
                )
                
                # Store the anchor mapping with its confidence
                anchors[(f'{c1_id}', f'{c2_id}')] = confidence
    
    return anchors

def compute_structural_confidence(node1, node2, ontology1, ontology2):
    """
    Compute the structural confidence between two ontology nodes.
    """
    def canonical(n):
        """Extract a canonical label for comparison."""
        if hasattr(n, 'label') and n.label:
            return n.label[0]
        elif hasattr(n, 'iri'):
            return get_local_name(n.iri)
        else:
            return str(n)
    
    # Get parents and children of the nodes
    c1_parents = {canonical(p) for p in ontology1.get_parents_of(node1)}
    c1_children = {canonical(c) for c in ontology1.get_children_of(node1)}
    c2_parents = {canonical(p) for p in ontology2.get_parents_of(node2)}
    c2_children = {canonical(c) for c in ontology2.get_children_of(node2)}
    
    # Combine parents and children into a single set for each node
    set1 = c1_parents | c1_children
    set2 = c2_parents | c2_children
    
    # Compute Jaccard similarity on tokenized labels
    return jaccard_similarity_tokens(set1, set2)

def normalize_label(label):
    """
    Normalize a label by lowercasing, removing punctuation, and tokenizing.
    Returns a set of tokens.
    """
    label = label.lower().strip()
    label = re.sub(r'[^\w\s]', '', label)  # Remove punctuation
    tokens = label.split()
    return set(tokens)

def jaccard_similarity_tokens(set1, set2):
    """
    Compute the Jaccard similarity between two sets of tokenized labels.
    """
    tokens1 = set.union(*(normalize_label(s) for s in set1))
    tokens2 = set.union(*(normalize_label(s) for s in set2))
    
    intersection = tokens1 & tokens2
    union = tokens1 | tokens2
    return len(intersection) / len(union) if union else 0.0

anchors = compute_anchors(source_index[0], target_index[0], source_ontology.ontology, target_ontology.ontology)
print(anchors)
# Out:
# {('116', '2442'): 0.0, ('1812', '2870'): 0.0, ('1917', '2862'): 0.0, ('19', '308'): 0.0, ('169', '1056'): 0.0, ('2115', '2457'): 0.0, ('507', '2597'): 0.25, ('2547', '1055'): 0.0, ('2341', '3279'): 0.5, ('813', '2900'): 0.0, ('1417', '1359'): 0.0, ('2507', '1178'): 0.0, ('1403', '1818'): 0.0, ('492', '287'): 0.0, ('1665', '26'): 0.0, ('2087', '1843'): 0.0, ('1430', '719'): 0.0, ('100', '232'): 0.0, ('177', '2974'): 0.0, ('476', '282'): 0.0, ('971', '3040'): 0.0, ('473', '148'): 0.0, ('955', '1426'): 0.0, ('407', '69'): 0.0, ('395', '259'): 0.0, ('503', '453'): 0.0, ('1651', '2884'): 0.0, ('68', '304'): 0.0, ('118', '898'): 0.0, ('2012', '3158'): 0.5, ('1683', '2905'): 0.16666666666666666, ('2249', '1837'): 0.14285714285714285, ('2189', '3245'): 1.0, ('1773', '2934'): 0.0, ('420', '1822'): 0.0, ('1883', '93'): 0.0, ('451', '1054'): 0.0, ('2257', '3253'): 0.0, ('1990', '2557'): 0.0, ('1443', '2244'): 0.0, ('2453', '3244'): 0.5, ('2151', '733'): 0.0, ('410', '1745'): 0.0, ('443', '288'): 0.1, ('38', '221'): 0.0, ('403', '249'): 0.0, ('2127', '3223'): 0.0, ('2120', '2011'): 0.16666666666666666, ('781', '2943'): 0.0, ('2363', '3178'): 0.5, ('1399', '3059'): 0.0, ('214', '274'): 0.0, ('321', '187'): 0.0, ('365', '681'): 0.0, ('2000', '1339'): 0.0, ('2572', '1074'): 0.0, ('506', '2384'): 0.25, ('2530', '620'): 0.0, ('1998', '601'): 0.5, ('1190', '560'): 0.0, ('1030', '2503'): 0.0, ('2706', '1197'): 0.0, ('2553', '2994'): 0.0, ('1119', '753'): 0.0, ('2262', '3015'): 0.0, ('2480', '2909'): 0.0, ('2568', '1386'): 0.0, ('2515', '199'): 0.0, ('494', '286'): 0.0, ('270', '270'): 0.0, ('1992', '618'): 0.0, ('2529', '1079'): 0.0, ('519', '104'): 0.0, ('2450', '3228'): 0.5, ('460', '138'): 0.0, ('2377', '3184'): 0.5, ('1337', '3126'): 0.0, ('425', '62'): 0.2, ('1863', '2599'): 0.0, ('1309', '845'): 0.0, ('1850', '1496'): 0.0, ('139', '272'): 0.058823529411764705, ('2124', '3222'): 1.0, ('776', '1600'): 0.0, ('524', '296'): 0.14285714285714285, ('1265', '2584'): 0.0, ('560', '1143'): 0.0, ('450', '917'): 0.0, ('2677', '2226'): 0.0, ('470', '144'): 0.14285714285714285, ('20', '683'): 0.0, ('2010', '2521'): 0.0, ('217', '339'): 0.0, ('1227', '344'): 0.0, ('1607', '72'): 0.0, ('24', '227'): 0.0, ('2123', '3221'): 0.0, ('2563', '1061'): 0.0, ('2569', '1545'): 0.0, ('1256', '1034'): 0.0, ('1579', '1487'): 0.0, ('2566', '1073'): 0.0, ('1847', '1276'): 0.0, ('209', '338'): 0.0, ('1970', '2152'): 0.25, ('210', '340'): 0.0, ('2597', '1880'): 0.25, ('1420', '3123'): 0.0, ('962', '330'): 0.0, ('1580', '1489'): 0.0, ('374', '627'): 0.0, ('1210', '3036'): 0.2, ('961', '328'): 0.0, ('2135', '2585'): 0.0, ('1989', '3156'): 1.0, ('2565', '1069'): 0.0, ('249', '1395'): 0.0, ('1560', '1124'): 0.0, ('877', '204'): 0.0, ('493', '713'): 0.0, ('2463', '3296'): 0.0, ('126', '1486'): 0.2, ('515', '94'): 0.07692307692307693, ('1056', '2883'): 0.25, ('2528', '1080'): 0.0, ('954', '313'): 0.0, ('495', '498'): 0.0, ('2343', '3168'): 0.5, ('1670', '1423'): 0.0, ('1402', '1146'): 0.0, ('525', '44'): 0.0, ('127', '1583'): 0.0, ('472', '146'): 0.0, ('2578', '1447'): 0.0, ('1308', '637'): 0.0, ('860', '126'): 0.0, ('2446', '3294'): 0.5, ('402', '246'): 0.0, ('2554', '1592'): 0.3333333333333333, ('247', '316'): 0.0, ('2614', '1014'): 0.0, ('2381', '3187'): 0.5, ('2406', '3287'): 0.0, ('2364', '3179'): 0.5, ('2351', '3172'): 0.5, ('36', '225'): 0.0, ('2459', '2558'): 0.0, ('963', '2017'): 0.0, ('2089', '3069'): 0.0, ('2357', '3282'): 0.5, ('2723', '2301'): 0.0, ('72', '600'): 0.0, ('2130', '3064'): 0.0, ('2342', '3280'): 0.5, ('260', '349'): 0.0, ('379', '673'): 0.0625, ('15', '611'): 0.0, ('2314', '3026'): 0.0, ('187', '2098'): 0.0, ('455', '290'): 0.1, ('130', '2963'): 0.0, ('393', '244'): 0.0, ('2378', '3185'): 0.5, ('88', '234'): 0.0, ('778', '2944'): 0.0, ('404', '74'): 0.0, ('1340', '1839'): 0.0, ('1428', '649'): 0.0, ('2091', '3219'): 1.0, ('45', '1113'): 0.0, ('348', '2958'): 0.0, ('78', '235'): 0.0, ('1555', '111'): 0.0, ('478', '168'): 0.0, ('947', '335'): 0.0, ('323' ...

# %%
# see anchors values
for key, value in anchors.items():
    print(key, value)
# Out:
# ('2342,buccinator', '3280,Buccinator') 0.5
# ('2440,scalenus dorsalis', '3214,Scalenus_Dorsalis') 0.5
# ('7,trunk', '122,Trunk') 0.0
# ('1668,tongue epithelium', '2925,Tongue_Epithelium') 0.0
# ('2533,cerumen', '1398,Cerumen') 0.0
# ('393,gastrointestinal system', '244,Gastrointestinal_System') 0.0
# ('2426,peroneus longus', '3291,Peroneus_Longus') 0.5
# ('2096,posterior cerebral artery', '747,Posterior_Cerebral_Artery') 0.0
# ('301,semicircular duct', '1171,Semicircular_Duct') 0.1
# ('1202,parasympathetic ganglion', '2999,Parasympathetic_Ganglion') 0.0
# ('1210,enteric ganglion', '3036,Enteric_Ganglion') 0.2
# ('971,cingulate cortex', '3040,Cingulate_Cortex') 0.0
# ('420,incisor', '1822,Incisor') 0.0
# ('2476,exocrine system', '641,Exocrine_System') 0.0
# ('2536,feces', '1052,Feces') 0.0
# ('1399,sternal manubrium', '3059,Sternal_Manubrium') 0.0
# ('2091,perineal artery', '3219,Perineal_Artery') 1.0
# ('473,myometrium', '148,Myometrium') 0.0
# ('424,esophagus', '53,Esophagus') 0.16666666666666666
# ('2056,intercostal artery', '1876,Intercostal_Artery') 0.0
# ('1839,prepuce epithelium', '2911,Prepuce_Epithelium') 0.0
# ('366,phalanx', '2271,Phalanx') 0.125
# ('2494,coronary artery', '761,Coronary_Artery') 0.0
# ('344,nasal turbinate', '2972,Nasal_Turbinate') 0.0
# ('2478,palate', '21,Palate') 0.0
# ('522,segmental bronchus', '2424,Segmental_Bronchus') 1.0
# ('493,seminal vesicle', '713,Seminal_Vesicle') 0.0
# ('159,cerebral hemisphere', '209,Cerebral_Hemisphere') 0.0
# ('2456,sternothyroid', '3260,Sternothyroid') 0.5
# ('1324,medial palpebral ligament', '3054,Medial_Palpebral_Ligament') 0.5
# ('2388,iliacus', '1815,Iliacus') 0.0
# ('70,hematopoietic system', '301,Hematopoietic_System') 0.0
# ('2078,inferior mesenteric artery', '1833,Inferior_Mesenteric_Artery') 0.0
# ('2555,endolymph', '1591,Endolymph') 1.0
# ('2677,parathyroid gland capsule', '2226,Parathyroid_Gland_Capsule') 0.0
# ('766,aorta endothelium', '2853,Aorta_Endothelium') 0.0
# ('319,conjunctiva', '185,Conjunctiva') 0.0
# ('1372,macula', '1122,Macula') 0.0
# ('2259,pericardiacophrenic vein', '3256,Pericardiacophrenic_Vein') 1.0
# ('2517,visceral pleura', '2686,Visceral_Pleura') 0.0
# ('2014,communicating artery', '1199,Communicating_Artery') 0.0
# ('1972,corniculate cartilage', '1470,Corniculate_Cartilage') 0.0
# ('813,lymphatic vessel endothelium', '2900,Lymphatic_Vessel_Endothelium') 0.0
# ('1227,ganglion', '344,Ganglion') 0.0
# ('575,articular cartilage', '1271,Articular_Cartilage') 0.3333333333333333
# ('1038,anterior olfactory nucleus', '3037,Anterior_Olfactory_Nucleus') 0.0
# ('2551,bulbourethral gland secretion', '2996,Bulbourethral_Gland_Secretion') 0.0
# ('409,jejunum', '256,Jejunum') 0.0
# ('110,tricuspid valve', '721,Tricuspid_Valve') 0.0
# ('515,paranasal sinus', '94,Paranasal_Sinus') 0.07692307692307693
# ('2135,temporal artery', '2585,Temporal_Artery') 0.0
# ('2451,spinalis thoracis', '3239,Spinalis_Thoracis') 0.5
# ('271,sympathetic ganglion', '350,Sympathetic_Ganglion') 0.0
# ('776,capillary endothelium', '1600,Capillary_Endothelium') 0.0
# ('38,thoracic cavity', '221,Thoracic_Cavity') 0.0
# ('2407,longissimus cervicis', '3288,Longissimus_Cervicis') 0.0
# ('77,arteriole', '592,Arteriole') 0.0
# ('1809,decidua', '1517,Decidua') 0.0
# ('2457,styloglossus', '3261,Styloglossus') 0.5
# ('644,mesothelium', '2110,Mesothelium') 0.0
# ('2563,sputum', '1061,Sputum') 0.0
# ('331,retina', '191,Retina') 0.0
# ('128,fibrocartilage', '1677,Fibrocartilage') 0.0
# ('494,testis', '286,Testis') 0.0
# ('2723,posterior commissure', '2301,Posterior_Commissure') 0.0
# ('227,corpus callosum', '321,Corpus_Callosum') 0.0
# ('114,atrioventricular node', '1290,Atrioventricular_Node') 0.0
# ('2468,transversus thoracis', '3298,Transversus_Thoracis') 0.5
# ('45,shoulder', '1113,Shoulder') 0.0
# ('402,large intestine', '246,Large_Intestine') 0.0
# ('2025,ethmoidal artery', '3159,Ethmoidal_Artery') 1.0
# ('1282,stapes', '2479,Stapes') 0.0
# ('1883,maxillary sinus', '93,Maxillary_Sinus') 0.0
# ('443,kidney', '288,Kidney') 0.1
# ('2097,posterior communicating artery', '2302,Posterior_Communicating_Artery') 0.0
# ('2105,pulmonary artery', '701,Pulmonary_Artery') 0.14285714285714285
# ('1945,trachea cartilage', '2929,Trachea_Cartilage') 0.1
# ('560,descending aorta', '1143,Descending_Aorta') 0.0
# ('219,ventral thalamus', '3060,Ventral_Thalamus') 0.0
# ('2365,extensor digitorum longus', '3180,Extensor_Digitorum_Longus') 0.5
# ('2120,subclavian artery', '2011,Subclavian_Artery') 0.16666666666666666
# ('2351,constrictor vulvae', '3172,Constrictor_Vulvae') 0.5
# ('472,endometrium', '146,Endometrium') 0.0
# ('129,hyaline cartilage', '444,Hyaline_Cartilage') 0.0
# ('2422,pectineus', '3210,Pectineus') 0.5
# ('1240,lumbosacral plexus', '3127,Lumbosacral_Plexus') 0.0
# ('2095,popliteal artery', '2287,Popliteal_Artery') 1.0
# ('2356,deltoid', '1540,Deltoid') 0.5
# ('559,abdominal aorta', '1141,Abdominal_Aorta') 0.0
# ('1608,descending colon', '79,Descending_Colon') 0.0
# ('285,auditory system', '814,Auditory_System') 0.0
# ('329,lacrimal apparatus', '198,Lacrimal_Apparatus') 0.0
# ('860,nipple', '126,Nipple') 0.0
# ('2082,obturator artery', '2168,Obturator_Artery') 0.0
# ('460,vulva', '138,Vulva') 0.0
# ('2643,membranous urethra', '2100,Membranous_Urethra') 0.0
# ('2053,infraorbital artery', '3189,Infraorbital_Artery') 1.0
# ('2572,urine', '1074,Urine') 0.0
# ('2516,parietal pleura', '2236,Parietal_Pleura') 0.0
# ('2370,flexor digitorum profundus', '3182,Flexor_Digitorum_Profundus') 0.5
# ('1665,submandibular gland', '26,Submandibular_Gland') 0.0
# ('19,muscle', '308,Muscle') 0.0
# ('2425,pectoralis minor', '2248,Pectoralis_Minor') 0.0
# ('507,terminal bronchiole', '2597,Terminal_Bronchiole') 0.25
# ('2441,scalenus medius', '3215,Scalenus_Medius') 0.5
# ('1104,cuneate nucleus', '3043,Cuneate_Nucleus') 0.0
# ('153,parathyroid gland', '692,Parathyroid_Gland') 0.0
# ('774,artery endothelium', '2857,Artery_Endothelium') 0.0
# ('2346,cleidooccipital', '3171,Cleidooccipital') 0.5
# ('1393,nasal cavity respiratory epithelium', '2903,Nasal_Cavity_Respiratory_Epithelium') 0.0
# ('2167,cerebellar vein', '3238,Cerebellar_Vein') 0.25
# ('2510,submandibular ganglion', '3000,Submandibular_Ganglion') 0.5
# ('2522,bile canaliculus', '1316,Bile_Canaliculus') 0.0
# ('1358,pupil', '2353,Pupil') 0.0
# ('2556,perilymph', '2258,Perilymph') 1.0
# ('1683,oropharynx epithelium', '2905,Oropharynx_Epithelium') 0.16666666666666666
# ('1555,mandible', '111,Mandible') 0.0
# ('296,saccule', '2072,Saccule') 0.0
# ('1576,sacroiliac joint', '2413,Sacroiliac_Joint') 0.0
# ('2444,semispinalis cervicis', '3218,Semispinalis_Cervicis') 0.5
# ('1671,fungiform papilla', '1720,Fungiform_Papilla') 0.0
# ('470,uterus', '144,Uterus') 0.14285714285714285
# ('476,vagina', '282,Vagina') 0.0
# ('2257,ophthalmic plexus', '3253,Ophthalmic_Plexus') 0.0
# ('214,pituitary gland', '274,Pituitary_Gland') 0.0
# ('292,membranous labyrinth', '1433,Membranous_Labyrinth') 0.0
# ('1430,tibia', '719,Tibia') 0.0
# ('1885,hypopharynx', '48,Hypopharynx') 0.0
# ('2513,cheek', '933,Cheek') 0.0
# ('1397,scapula', '710,Scapula') 0.0
# ('2260,pancreatic vein', '3255,Pancreatic_Vein') 1.0
# ('2139,thoracodorsal artery', '3229,Thoracodorsal_Artery') 1.0
# ('423,pharynx', '49,Pharynx') 0.0
# ('2392,iliothoracic', '3191,Iliothoracic') 0.5
# ('957,globus pallidus', '326,Globus_Pallidus') 0.0
# ('2130,inferior suprarenal artery', '3064,Inferior_Suprarenal_Artery') 0.0
# ('2012,cervical artery', '3158,Cervical_Artery') 0.5
# ('2377,genioglossus', '3184,Genioglossus') 0.5
# ('1138,corpora quadrigemina', '342,Corpora_Quadrigemina') 0.0
# ('1579,costochondral joint', '1487,Costochondral_Joint') 0.0
# ('1340,oculomotor muscle', '1839,Oculomotor_Muscle') 0.0
# ('79,capillary', '610,Capillary') 0.0
# ('382,thoracic vertebra', '718,Thoracic_Vertebra') 0.03333333333333333
# ('2433,quadratus lumborum', '2363,Quadratus_Lumborum') 0.0
# ('72,vascular system', '600,Vascular_System') 0.0
# ('364,metacarpal bone', '680,Metacarpal_Bone') 0.0
# ('2449,serratus ventralis', '3227,Serratus_Ventralis') 0.5
# ('323,eyelid', '642,Eyelid') 0.0
# ('217,thalamus', '339,Thalamus') 0.0
# ('1402,acetabulum', '1146,Acetabulum') 0.0
# ('124,cartilage', '102,Cartilage') 0.0
# ('1233,brachial plexus', '602,Brachial_Plexus') 0.0
# ('1417,calcaneum', '1359,Calcaneum') 0.0
# ('781,venule endothelium', '2943,Venule_Endothelium') 0.0
# ('365,metatarsal bone', '681,Metatarsal_Bone') 0.0
# ('316,choroid', '193,Choroid') 0.0
# ('2463,thyrohyoid', '3296,Thyrohyoid') 0.0
# ('252,substantia nigra', '331,Substantia_Nigra') 0.0
# ('2566,sweat', '1073,Sweat') 0.0
# ('2249,mesenteric vein', '1837,Mesenteric_Vein') 0.14285714285714285
# ('1607,ascending colon', '72,Ascending_Colon') 0.0
# ('2345,cleidocephalic', '3170,Cleidocephalic') 0.5
# ('1947,trachea submucosa', '2932,Trachea_Submucosa') 0.0
# ('2505,labium', '137,Labium') 0.0
# ('422,oropharynx', '41,Oropharynx') 0.0
# ('2530,cerebrospinal fluid', '620,Cerebrospinal_Fluid') 0.0
# ('2115,spermatic artery', '2457,Spermatic_Artery') 0.0
# ('1917,bronchus connective tissue', '2862,Bronchus_Connective_Tissue') 0.0
# ('947,subthalamic nucleus', '335,Subthalamic_Nucleus') 0.0
# ('2343,bulboglandular', '3168,Bulboglandular') 0.5
# ('2614,mesangium', '1014,Mesangium') 0.0
# ('2378,geniohyoid', '3185,Geniohyoid') 0.5
# ('490,penis', '163,Penis') 0.0
# ('1420,talus', '3123,Talus') 0.0
# ('307,tympanic membrane', '388,Tympanic_Membrane') 0.0
# ('1847,arytenoid cartilage', '1276,Arytenoid_Cartilage') 0.0
# ('406,small intestine', '71,Small_Intestine') 0.0
# ('1009,auditory cortex', '3039,Auditory_Cortex') 0.0
# ('24,skeletal system', '227,Skeletal_System') 0.0
# ('2000,bronchial artery', '1339,Bronchial_Artery') 0.0
# ('1275,posterior semicircular canal', '2322,Posterior_Semicircular_Canal') 0.0
# ('525,nasopharynx', '44,Nasopharynx') 0.0
# ('2447,serratus dorsalis caudalis', '3225,Serratus_Dorsalis_Caudalis') 0.5
# ('1308,corneal endothelium', '637,Corneal_Endothelium') 0.0
# ('1225,thoracic ganglion', '3139,Thoracic_Ganglion') 0.0
# ('451,renal corpuscle', '1054,Renal_Corpuscle') 0.0
# ('16,endocrine system', '466,Endocrine_System') 0.0
# ('2570,enamel', '1589,Enamel') 0.0
# ('2553,seminal vesicle secretion', '2994,Seminal_Vesicle_Secretion') 0.0
# ('1123,spinal vestibular nucleus', '2462,Spinal_Vestibular_Nucleus') 0.0
# ('855,lactiferous duct', '1951,Lactiferous_Duct') 0.0
# ('1990,suprarenal artery', '2557,Suprarenal_Artery') 0.0
# ('2569,dentin', '1545,Dentin') 0.0
# ('274,peripheral nerve', '694,Peripheral_Nerve') 0.03333333333333333
# ('408,ileum', '255,Ileum') 0.0
# ('955,claustrum', '1426,Claustrum') 0.0
# ('2515,orbit', '199,Orbit') 0.0
# ('78,artery', '235,Artery') 0.0
# ('1117,medial vestibular nucleus', '2092,Medial_Vestibular_Nucleus') 0.0
# ('309,auricle', '1245,Auricle') 0.0
# ('1318,eyelid subcutaneous connective tissue', '2878,Eyelid_Subcutaneous_Connective_Tissue') 0.0
# ('403,cecum', '249,Cecum') 0.0
# ('204,brain', '207,Brain') 0.16666666666666666
# ('495,seminiferous tubule', '498,Seminiferous_Tubule') 0.0
# ('877,meninges', '204,Meninges') 0.0
# ('519,bronchus', '104,Bronchus') 0.0
# ('1320,orbicularis oculi', '3165,Orbicularis_Oculi') 0.3333333333333333
# ('20,musculoskeletal system', '683,Musculoskeletal_System') 0.0
# ('1256,basilar membrane', '1034,Basilar_Membrane') 0.0
# ('2151,vertebral artery', '733,Vertebral_Artery') 0.0
# ('1852,thyroid cartilage', '2619,Thyroid_Cartilage') 0.0
# ('1190,substantia gelatinosa', '560,Substantia_Gelatinosa') 0.0
# ('2458,subscapularis', '2506,Subscapularis') 0.0
# ('2507,perineum', '1178,Perineum') 0.0
# ('503,alveolus', '453,Alveolus') 0.0
# ('1811,cervix epithelium', '2869,Cervix_Epithelium') 0.14285714285714285
# ('2455,sternooccipital', '3259,Sternooccipital') 0.5
# ('1425,humerus', '661,Humerus') 0.0
# ('1863,bronchiole epithelium', '2599,Bronchiole_Epithelium') 0.0
# ('1851,epiglottic cartilage', '1605,Epiglottic_Cartilage') 0.0
# ('295,vestibular labyrinth', '548,Vestibular_Labyrinth') 0.0
# ('1266,vestibular membrane', '2099,Vestibular_Membrane') 0.0
# ('1429,fibula', '651,Fibula') 0.0
# ('1812,cervix squamous epithelium', '2870,Cervix_Squamous_Epithelium') 0.0
# ('168,intestine', '247,Intestine') 0.2
# ('147,pancreatic duct', '85,Pancreatic_Duct') 0.1111111111111111
# ('2568,cementum', '1386,Cementum') 0.0
# ('2448,serratus dorsalis cranialis', '3226,Serratus_Dorsalis_Cranialis') 0.5
# ('2467,transversus abdominis', '3297,Transversus_Abdominis') 0.0
# ('777,vein endothelium', '2941,Vein_Endothelium') 0.0
# ('1056,fourth ventricle ependyma', '2883,Fourth_Ventricle_Ependyma') 0.25
# ('2728,internal capsule', '946,Internal_Capsule') 0.0
# ('381,sacral vertebra', '774,Sacral_Vertebra') 0.07142857142857142
# ('455,urethra', '290,Urethra') 0.1
# ('232,lateral ventricle', '752,Lateral_Ventricle') 0.0
# ('2079,superior mesenteric artery', '2537,Superior_Mesenteric_Artery') 0.0
# ('2262,inferior pancreatico-duodenal vein', '3015,Inferior_Pancreatico-Duodenal_Vein') 0.0
# ('2357,depressor labii inferioris', '3282,Depressor_Labii_Inferioris') 0.5
# ('405,rectum', '257,Rectum') 0.0
# ('2408,longissimus lumborum', '3197,Longissimus_Lumborum') 0.5
# ('1443,patella', '2244,Patella') 0.0
# ('767,arterial system endothelium', '2952,Arterial_System_Endothelium') 0.0
# ('1403,ilium', '1818,Ilium') 0.0
# ('2083,occipital artery', '2172,Occipital_Artery') 0.0
# ('130,intervertebral disc', '2963,Intervertebral_Disc') 0.0
# ('2419,omotransverse', '3207,Omotransverse') 0.5
# ('143,pancreas', '82,Pancreas') 0.25
# ('1428,femur', '649,Femur') 0.0
# ('2423,pectoralis major', '2246,Pectoralis_Major') 0.0
# ('2381,gracilis', '3187,Gracilis') 0.5
# ('917,arcuate nucleus', '3038,Arcuate_Nucleus') 0.0
# ('1989,alveolar artery', '3156,Alveolar_Artery') 1.0
# ('2239,masseteric vein', '3250,Masseteric_Vein') 1.0
# ('2480,pancreatic acinus', '2909,Pancreatic_Acinus') 0.0
# ('1396,clavicle', '624,Clavicle') 0.0
# ('1309,corneal epithelium', '845,Corneal_Epithelium') 0.0
# ('2472,urethralis', '3002,Urethralis') 0.5
# ('2587,axillary artery', '1293,Axillary_Artery') 1.0
# ('959,accumbens nucleus', '3061,Accumbens_Nucleus') 0.0
# ('100,myocardium', '232,Myocardium') 0.0
# ('126,costal cartilage', '1486,Costal_Cartilage') 0.2
# ('1034,lateral ventricle ependyma', '2892,Lateral_Ventricle_Ependyma') 0.25
# ('2446,semitendinosus', '3294,Semitendinosus') 0.5
# ('2693,eyelash', '1656,Eyelash') 0.0
# ('1737,glomerulus', '1053,Glomerulus') 0.0
# ('2127,superficial cervical artery', '3223,Superficial_Cervical_Artery') 0.0
# ('492,scrotum', '287,Scrotum') 0.0
# ('2189,epigastric vein', '3245,Epigastric_Vein') 1.0
# ('2009,cerebellar artery', '3153,Cerebellar_Artery') 0.0
# ('2123,subcostal artery', '3221,Subcostal_Artery') 0.0
# ('419,tooth', '392,Tooth') 0.0
# ('404,colon', '74,Colon') 0.0
# ('2409,longissimus thoracis', '3289,Longissimus_Thoracis') 0.5
# ('2679,filiform papilla', '1681,Filiform_Papilla') 0.0
# ('14,connective tissue', '237,Connective_Tissue') 0.038461538461538464
# ('2452,splenius', '3295,Splenius') 0.0
# ('68,blood', '304,Blood') 0.0
# ('134,ligament', '153,Ligament') 0.0
# ('2475,zygomaticus', '3300,Zygomaticus') 0.0
# ('2301,suprarenal vein', '3272,Suprarenal_Vein') 0.2
# ('1739,glomerular capillary', '1601,Glomerular_Capillary') 0.25
# ('264,autonomic ganglion', '351,Autonomic_Ganglion') 0.1
# ('139,endocrine gland', '272,Endocrine_Gland') 0.058823529411764705
# ('1998,brachial artery', '601,Brachial_Artery') 0.5
# ('2124,sublingual artery', '3222,Sublingual_Artery') 1.0
# ('61,pericardial cavity', '2752,Pericardial_Cavity') 0.3333333333333333
# ('2054,inferior epigastric artery', '3163,Inferior_Epigastric_Artery') 0.0
# ('1921,bronchus cartilage', '2861,Bronchus_Cartilage') 0.1111111111111111
# ('2585,ascending aorta', '1278,Ascending_Aorta') 0.0
# ('506,respiratory bronchiole', '2384,Respiratory_Bronchiole') 0.25
# ('464,ovary', '280,Ovary') 0.0
# ('1670,circumvallate papilla', '1423,Circumvallate_Papilla') 0.0
# ('1995,auricular artery', '3157,Auricular_Artery') 1.0
# ('1289,tympanic epithelium', '2933,Tympanic_Epithelium') 0.0
# ('109,pulmonary valve', '702,Pulmonary_Valve') 0.0
# ('2087,pancreatico-duodenal artery', '1843,Pancreatico-Duodenal_Artery') 0.0
# ('1280,incus', '1823,Incus') 0.0
# ('1918,bronchus basement membrane', '2860,Bronchus_Basement_Membrane') 0.0
# ('1833,seminal vesicle epithelium', '2921,Seminal_Vesicle_Epithelium') 0.0
# ('2418,omohyoid', '3206,Omohyoid') 0.5
# ('1315,meibomian gland', '2097,Meibomian_Gland') 0.0
# ('2450,sphincter colli superficialis', '3228,Sphincter_Colli_Superficialis') 0.5
# ('173,spleen', '302,Spleen') 0.14285714285714285
# ('2424,pectoralis muscle', '2247,Pectoralis_Muscle') 0.14285714285714285
# ('963,lentiform nucleus', '2017,Lentiform_Nucleus') 0.0
# ('1338,orbitalis muscle', '3124,Orbitalis_Muscle') 0.0
# ('772,arteriole endothelium', '2855,Arteriole_Endothelium') 0.0
# ('176,tonsil', '32,Tonsil') 0.0
# ('1850,cricoid cartilage', '1496,Cricoid_Cartilage') 0.0
# ('231,hippocampus', '318,Hippocampus') 0.0
# ('2092,peroneal artery', '2270,Peroneal_Artery') 0.0
# ('465,gonad', '656,Gonad') 0.0
# ('290,cochlea', '261,Cochlea') 0.0
# ('249,cerebral aqueduct', '1395,Cerebral_Aqueduct') 0.0
# ('778,venous system endothelium', '2944,Venous_System_Endothelium') 0.0
# ('2464,tibialis caudalis', '3266,Tibialis_Caudalis') 0.5
# ('2565,sebum', '1069,Sebum') 0.0
# ('2089,superior pancreatico-duodenal artery', '3069,Superior_Pancreatico-Duodenal_Artery') 0.0
# ('116,sinoatrial node', '2442,Sinoatrial_Node') 0.0
# ('2341,brachialis', '3279,Brachialis') 0.5
# ('2038,gastroepiploic artery', '3161,Gastroepiploic_Artery') 1.0
# ('1864,respiratory bronchiole epithelium', '2843,Respiratory_Bronchiole_Epithelium') 0.0
# ('505,bronchiole', '608,Bronchiole') 0.0
# ('2502,vitreous chamber', '2689,Vitreous_Chamber') 0.0
# ('2363,extensor digitorum communis', '3178,Extensor_Digitorum_Communis') 0.5
# ('1365,nasolacrimal duct', '2153,Nasolacrimal_Duct') 0.0
# ('1398,sternum', '715,Sternum') 0.0
# ('1404,ischium', '1932,Ischium') 0.0
# ('1360,lacrimal canaliculus', '1949,Lacrimal_Canaliculus') 0.0
# ('410,gingiva', '1745,Gingiva') 0.0
# ('2528,plasma', '1080,Plasma') 0.0
# ('187,sebaceous gland', '2098,Sebaceous_Gland') 0.0
# ('2010,superior cerebellar artery', '2521,Superior_Cerebellar_Artery') 0.0
# ('458,female reproductive system', '160,Female_Reproductive_System') 0.0
# ('337,respiratory system', '297,Respiratory_System') 0.0
# ('2125,subscapular artery', '2505,Subscapular_Artery') 0.0
# ('961,caudate nucleus', '328,Caudate_Nucleus') 0.0
# ('1580,costovertebral joint', '1489,Costovertebral_Joint') 0.0
# ('210,hypothalamus', '340,Hypothalamus') 0.0
# ('2404,levator nasolabialis', '3195,Levator_Nasolabialis') 0.5
# ('459,clitoris', '140,Clitoris') 0.0
# ('2406,longissimus capitis', '3287,Longissimus_Capitis') 0.0
# ('15,cardiovascular system', '611,Cardiovascular_System') 0.0
# ('2088,inferior pancreatico-duodenal artery', '1842,Inferior_Pancreatico-duodenal_artery') 0.0
# ('2393,infraspinatus', '1854,Infraspinatus') 0.0
# ('453,ureter', '289,Ureter') 0.1
# ('407,duodenum', '69,Duodenum') 0.0
# ('2541,esophagus secretion', '2997,Esophagus_Secretion') 0.0
# ('1582,sternocostal joint', '2484,Sternocostal_Joint') 0.0
# ('28,thorax', '709,Thorax') 0.0
# ('2547,lymph', '1055,Lymph') 0.0
# ('127,elastic cartilage', '1583,Elastic_Cartilage') 0.0
# ('321,cornea', '187,Cornea') 0.0
# ('2314,superficial temporal vein', '3026,Superficial_Temporal_Vein') 0.0
# ('136,tendon', '915,Tendon') 0.0
# ('209,epithalamus', '338,Epithalamus') 0.0
# ('425,stomach', '62,Stomach') 0.2
# ('2529,serum', '1079,Serum') 0.0
# ('2445,semispinalis thoracis', '3224,Semispinalis_Thoracis') 0.5
# ('2473,vastus lateralis', '3263,Vastus_Lateralis') 0.5
# ('2355,cutaneous trunci', '3173,Cutaneous_Trunci') 0.5
# ('247,medulla oblongata', '316,Medulla_Oblongata') 0.0
# ('373,vertebra', '622,Vertebra') 0.0
# ('891,choroid plexus epithelium', '2787,Choroid_Plexus_Epithelium') 0.08333333333333333
# ('962,putamen', '330,Putamen') 0.0
# ('87,venule', '732,Venule') 0.0
# ('165,lymphoid tissue', '419,Lymphoid_Tissue') 0.0
# ('389,joint', '357,Joint') 0.0
# ('2561,lung surfactant', '1066,Lung_Surfactant') 0.0
# ('2421,parotidoauricular', '3209,Parotidoauricular') 0.5
# ('169,lymphatic vessel', '1056,Lymphatic_Vessel') 0.0
# ('417,tongue', '20,Tongue') 0.0
# ('278,sensory ganglion', '653,Sensory_Ganglion') 0.14285714285714285
# ('37,chest', '874,Chest') 0.0
# ('299,semicircular canal', '1450,Semicircular_Canal') 0.0
# ('2414,mylohyoid', '3201,Mylohyoid') 0.5
# ('1265,tectorial membrane', '2584,Tectorial_Membrane') 0.0
# ('260,nerve', '349,Nerve') 0.0
# ('2344,cleidobrachial', '3169,Cleidobrachial') 0.5
# ('189,dermis', '633,Dermis') 0.0
# ('2261,pancreatico-duodenal vein', '3016,Pancreatico-Duodenal_Vein') 0.2
# ('190,epidermis', '638,Epidermis') 0.0
# ('2077,mesenteric artery', '1834,Mesenteric_Artery') 0.0
# ('1248,modiolus', '2131,Modiolus') 0.0
# ('297,utricle', '2074,Utricle') 0.0
# ('2680,foliate papilla', '1695,Foliate_Papilla') 0.0
# ('1281,malleus', '2078,Malleus') 0.0
# ('2597,interlobular artery', '1880,Interlobular_Artery') 0.25
# ('1952,nasopharynx epithelium', '2904,Nasopharynx_Epithelium') 0.14285714285714285
# ('239,cerebellum', '319,Cerebellum') 0.0
# ('395,hepatobiliary system', '259,Hepatobiliary_System') 0.0
# ('75,aorta', '587,Aorta') 0.0
# ('240,cerebellar cortex', '2849,Cerebellar_Cortex') 0.0
# ('177,oropharyngeal lymphoid tissue', '2974,Oropharyngeal_Lymphoid_Tissue') 0.0
# ('1651,gingival epithelium', '2884,Gingival_Epithelium') 0.0
# ('377,cervical vertebra', '621,Cervical_Vertebra') 0.05555555555555555
# ('88,heart', '234,Heart') 0.0
# ('1923,bronchus submucosa', '2866,Bronchus_Submucosa') 0.0
# ('1577,sternoclavicular joint', '2482,Sternoclavicular_Joint') 0.0
# ('2435,rectus abdominis', '2371,Rectus_Abdominis') 0.0
# ('2590,atrioventricular bundle', '1289,Atrioventricular_Bundle') 0.0
# ('2554,otolymph', '1592,Otolymph') 0.3333333333333333
# ('1609,transverse colon', '253,Transverse_Colon') 0.0
# ('2297,superior intercostal vein', '2532,Superior_Intercostal_Vein') 0.5
# ('2453,sternohyoid', '3244,Sternohyoid') 0.5
# ('628,perineal muscle', '2261,Perineal_Muscle') 0.3333333333333333
# ('2549,semen', '506,Semen') 0.0
# ('268,parasympathetic nervous system', '690,Parasympathetic_Nervous_System') 0.0
# ('1045,olfactory tract', '2183,Olfactory_Tract') 0.0
# ('1970,nasal cartilage', '2152,Nasal_Cartilage') 0.25
# ('852,areola', '229,Areola') 0.0
# ('2063,lacrimal artery', '3194,Lacrimal_Artery') 1.0
# ('2442,semimembranosus', '3216,Semimembranosus') 0.5
# ('2689,submandibular duct', '2504,Submandibular_Duct') 0.2
# ('954,amygdala', '313,Amygdala') 0.0
# ('2364,extensor digitorum lateralis', '3179,Extensor_Digitorum_Lateralis') 0.5
# ('1865,terminal bronchiole epithelium', '2598,Terminal_Bronchiole_Epithelium') 0.0
# ('148,exocrine pancreas', '87,Exocrine_Pancreas') 0.0
# ('2292,subclavian vein', '716,Subclavian_Vein') 0.3333333333333333
# ('838,palatine tonsil', '2217,Palatine_Tonsil') 1.0
# ('1330,palpebral conjunctiva', '829,Palpebral_Conjunctiva') 0.0
# ('152,endocrine pancreas', '512,Endocrine_Pancreas') 0.0
# ('1337,levator palpebrae superioris', '3126,Levator_Palpebrae_Superioris') 0.0
# ('374,vertebral column', '627,Vertebral_Column') 0.0
# ('208,diencephalon', '337,Diencephalon') 0.0
# ('63,peritoneal cavity', '695,Peritoneal_Cavity') 0.3333333333333333
# ('2131,superior suprarenal artery', '3063,Superior_Suprarenal_Artery') 0.0
# ('379,lumbar vertebra', '673,Lumbar_Vertebra') 0.0625
# ('2459,supraspinatus', '2558,Supraspinatus') 0.0
# ('2578,colostrum', '1447,Colostrum') 0.0
# ('2484,soleus', '3264,Soleus') 0.5
# ('2379,gluteus maximus', '3001,Gluteus_Maximus') 0.5
# ('432,liver', '258,Liver') 0.2
# ('2400,ischiocavernosus', '3192,Ischiocavernosus') 0.5
# ('1702,falciform ligament', '1662,Falciform_Ligament') 0.0
# ('2706,anterior commissure', '1197,Anterior_Commissure') 0.0
# ('478,epididymis', '168,Epididymis') 0.0
# ('1773,urethra epithelium', '2934,Urethra_Epithelium') 0.0
# ('1986,diaphragm', '635,Diaphragm') 0.16666666666666666
# ('524,trachea', '296,Trachea') 0.14285714285714285
# ('1030,subiculum', '2503,Subiculum') 0.0
# ('491,prepuce', '161,Prepuce') 0.0
# ('1992,cerebral artery', '618,Cerebral_Artery') 0.0
# ('348,appendicular skeleton', '2958,Appendicular_Skeleton') 0.0
# ('1560,maxilla', '1124,Maxilla') 0.0
# ('118,pericardium', '898,Pericardium') 0.0
# ('2443,semispinalis capitis', '3217,Semispinalis_Capitis') 0.5
# ('2024,epigastric artery', '1527,Epigastric_Artery') 0.0
# ('2534,saliva', '1068,Saliva') 0.0
# ('1489,coccygeal vertebra', '1430,Coccygeal_Vertebra') 0.3333333333333333
# ('335,sclera', '711,Sclera') 0.0
# ('497,larynx', '99,Larynx') 0.0
# ('1941,trachea basement membrane', '2927,Trachea_Basement_Membrane') 0.0
# ('262,peripheral nervous system', '348,Peripheral_Nervous_System') 0.0
# ('1304,ciliary epithelium', '1416,Ciliary_Epithelium') 0.0
# ('36,pelvis', '225,Pelvis') 0.0
# ('450,nephron', '917,Nephron') 0.0
# ('397,reproductive system', '164,Reproductive_System') 0.0
# ('218,dorsal thalamus', '3044,Dorsal_Thalamus') 0.0
# ('270,sympathetic nervous system', '270,Sympathetic_Nervous_System') 0.0
# ('1119,nucleus ambiguus', '753,Nucleus_Ambiguus') 0.0

# %%
def get_neighbors(cls):
    """Retrieve parent and child classes for context expansion."""
    neighbors = set()
    
    # Retrieve superclass and subclass relations
    if hasattr(cls, "is_a"):
        neighbors.update(cls.is_a)  # Direct parent classes

    if hasattr(cls, "subclasses"):
        neighbors.update(cls.subclasses())  # Direct child classes

    return neighbors

def discover_new_mappings(ontology1, ontology2, anchors, threshold=0.8):
    new_mappings = {}

    for (c1, c2) in anchors:
        cls1 = ontology1.search_one(iri=f"*{c1}")  # Find class in ontology 1
        cls2 = ontology2.search_one(iri=f"*{c2}")  # Find class in ontology 2

        if not cls1 or not cls2:
            continue  # Skip if class not found
        
        neighbors1 = get_neighbors(cls1)
        neighbors2 = get_neighbors(cls2)

        for n1 in neighbors1:
            for n2 in neighbors2:
                if hasattr(n1, "label") and hasattr(n2, "label"):
                    label1 = n1.label[0] if n1.label else n1.name
                    label2 = n2.label[0] if n2.label else n2.name
                    sim = isub_similarity(label1, label2)
                    
                    if sim > threshold:
                        new_mappings[(n1.name, n2.name)] = sim  # Store class names

    return new_mappings

new_mappings = discover_new_mappings(source_ontology.ontology, target_ontology.ontology, anchors)
print(new_mappings)
# Out:
# {('Thing', 'Thing'): 1.0, ('MA_0000067', 'MA_0000067'): 1.0, ('MA_0001260', 'MA_0001260'): 1.0, ('MA_0001260', 'MA_0001257'): 0.8636363636363636, ('MA_0001257', 'MA_0001260'): 0.8636363636363636, ('MA_0001257', 'MA_0001257'): 1.0}

# %%
def check_unsatisfiability(ontology1, ontology2, mappings):
    """Detect unsatisfiable mappings based on logical conflicts."""
    conflicts = []

    for (c1, c2), confidence in mappings.items():
        cls1 = ontology1.search_one(iri=f"*{c1}")  # Find class in ontology 1
        cls2 = ontology2.search_one(iri=f"*{c2}")  # Find class in ontology 2

        if not cls1 or not cls2:
            continue  # Skip if class not found

        # Check if the classes are explicitly disjoint in their respective ontologies
        if hasattr(cls1, "disjoint_with") and cls2 in cls1.disjoint_with:
            conflicts.append((c1, c2))  # Add to conflicts if disjoint

        # Check if the classes belong to fundamentally different hierarchies
        if hasattr(cls1, "is_a") and hasattr(cls2, "is_a"):
            super1 = {superclass for superclass in cls1.is_a}
            super2 = {superclass for superclass in cls2.is_a}
            
            # If they have no common ancestors, they might be semantically incompatible
            if not super1.intersection(super2):
                conflicts.append((c1, c2))

    return conflicts

conflicts = check_unsatisfiability(source_ontology.ontology, target_ontology.ontology,new_mappings)
print(conflicts)
# Out:
# [('Thing', 'Thing')]

# %%
def repair_mappings(mappings, conflicts):
    for conflict in conflicts:
        if conflict in mappings:
            del mappings[conflict]
    return mappings

new_mappings = repair_mappings(new_mappings, conflicts)
print(new_mappings)
# Out:
# {('MA_0000067', 'MA_0000067'): 1.0, ('MA_0001260', 'MA_0001260'): 1.0, ('MA_0001260', 'MA_0001257'): 0.8636363636363636, ('MA_0001257', 'MA_0001260'): 0.8636363636363636, ('MA_0001257', 'MA_0001257'): 1.0}
